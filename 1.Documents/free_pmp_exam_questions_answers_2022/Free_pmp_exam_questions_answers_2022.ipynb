# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'free_pmp_exam_questions_answers_2022'
input_file = file_name + '.pdf'
output_file = file_name + '_statements.jsonl'

# %%
# open pdf and extract text
with pdfplumber.open(input_file) as pdf:
    all_text = ""
    for page in pdf.pages:
        all_text += '\n' + page.extract_text()

# %%
# remove the repeating header: \n© PMP Sample Paper with ANSWERS
header_pattern1 = r"\nPMP Sample Paper with ANSWERS"
all_text = re.sub(header_pattern1, '', all_text)
# remove the repeating header: \n200 PMP Q & A
header_pattern2 = r"\n200 PMP Q & A"
all_text = re.sub(header_pattern2, '', all_text)
# remove the repeating footer: \n© Projex Academy 2022 | www.projex.com/pmp \d+
footer_pattern = r"\n© Projex Academy 2022 \| www.projex.com/pmp \d+"
all_text = re.sub(footer_pattern, '', all_text)

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)
qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)
question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)
choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)
choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)
choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)
choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

# %%
answer_text="1 B 41 B 81 B 121 B 161 C\n2 A 42 D 82 B 122 A 162 A\n3 C 43 B 83 C 123 B 163 A\n4 C 44 A 84 D 124 D 164 B\n5 C 45 C 85 C 125 C 165 C\n6 B 46 D 86 D 126 C 166 A\n7 B 47 C 87 A 127 A 167 B\n8 B 48 D 88 A 128 B 168 A\n9 C 49 C 89 D 129 A 169 D\n10 B 50 A 90 C 130 B 170 B\n11 B 51 C 91 D 131 C 171 C\n12 D 52 C 92 D 132 C 172 A\n13 D 53 C 93 A 133 C 173 C\n14 D 54 C 94 D 134 B 174 A\n15 C 55 B 95 B 135 C 175 C\n16 C 56 A 96 A 136 A 176 B\n17 D 57 A 97 C 137 B 177 A\n18 B 58 C 98 A 138 C 178 C\n19 D 59 C 99 A 139 A 179 A\n20 C 60 B 100 A 140 C 180 C\n21 A 61 C 101 A 141 D 181 A\n22 A 62 B 102 A 142 D 182 A\n23 B 63 C 103 D 143 D 183 D\n24 A 64 D 104 A 144 C 184 C\n25 A 65 D 105 D 145 C 185 A\n26 B 66 B 106 C 146 D 186 B\n27 D 67 B 107 A 147 A 187 C\n28 C 68 B 108 C 148 D 188 D\n29 D 69 D 109 A 149 B 189 C\n30 D 70 D 110 A 150 A 190 B\n31 B 71 A 111 C 151 D 191 C\n32 D 72 A 112 D 152 B 192 D\n33 A 73 D 113 C 153 B 193 D\n34 D 74 B 114 C 154 B 194 B\n35 C 75 B 115 C 155 A 195 C\n36 C 76 C 116 B 156 B 196 B\n37 C 77 C 117 C 157 D 197 C\n38 B 78 C 118 D 158 A 198 D\n39 B 79 D 119 A 159 A 199 D\n40 D 80 C 120 B 160 B 200 B"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1 B 41 B 81 B 121 B 161 C 2 A 42 D 82 B 122 A 162 A 3 C 43 B 83 C 123 B 163 A 4 C 44 A 84 D 124 D 164 B 5 C 45 C 85 C 125 C 165 C 6 B 46 D 86 D 126 C 166 A 7 B 47 C 87 A 127 A 167 B 8 B 48 D 88 A 128 B 168 A 9 C 49 C 89 D 129 A 169 D 10 B 50 A 90 C 130 B 170 B 11 B 51 C 91 D 131 C 171 C 12 D 52 C 92 D 132 C 172 A 13 D 53 C 93 A 133 C 173 C 14 D 54 C 94 D 134 B 174 A 15 C 55 B 95 B 135 C 175 C 16 C 56 A 96 A 136 A 176 B 17 D 57 A 97 C 137 B 177 A 18 B 58 C 98 A 138 C 178 C 19 D 59 C 99 A 139 A 179 A 20 C 60 B 100 A 140 C 180 C 21 A 61 C 101 A 141 D 181 A 22 A 62 B 102 A 142 D 182 A 23 B 63 C 103 D 143 D 183 D 24 A 64 D 104 A 144 C 184 C 25 A 65 D 105 D 145 C 185 A 26 B 66 B 106 C 146 D 186 B 27 D 67 B 107 A 147 A 187 C 28 C 68 B 108 C 148 D 188 D 29 D 69 D 109 A 149 B 189 C 30 D 70 D 110 A 150 A 190 B 31 B 71 A 111 C 151 D 191 C 32 D 72 A 112 D 152 B 192 D 33 A 73 D 113 C 153 B 193 D 34 D 74 B 114 C 154 B 194 B 35 C 75 B 115 C 155 A 195 C 36 C 76 C 116 B 156 B 196 B 37 C 77 C 117 C 157 D 197 C 38 B 78 C 118 D 158 A 198 D 39 B 79 D 119 A 159 A 199 D 40 D 80 C 120 B 160 B 200 B

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom)-1):
    qn=pom[i]
    qa=pom[i+1]
    answer_dict[qn]=qa
answer_dict_new={}
for i in range(1,201):
    qn=str(i)
    answer_dict_new[qn]=answer_dict[qn]
answer_dict_new
# Out:
# {'1': 'B',
#  '2': 'A',
#  '3': 'C',
#  '4': 'C',
#  '5': 'C',
#  '6': 'B',
#  '7': 'B',
#  '8': 'B',
#  '9': 'C',
#  '10': 'B',
#  '11': 'B',
#  '12': 'D',
#  '13': 'D',
#  '14': 'D',
#  '15': 'C',
#  '16': 'C',
#  '17': 'D',
#  '18': 'B',
#  '19': 'D',
#  '20': 'C',
#  '21': 'A',
#  '22': 'A',
#  '23': 'B',
#  '24': 'A',
#  '25': 'A',
#  '26': 'B',
#  '27': 'D',
#  '28': 'C',
#  '29': 'D',
#  '30': 'D',
#  '31': 'B',
#  '32': 'D',
#  '33': 'A',
#  '34': 'D',
#  '35': 'C',
#  '36': 'C',
#  '37': 'C',
#  '38': 'B',
#  '39': 'B',
#  '40': 'D',
#  '41': 'B',
#  '42': 'D',
#  '43': 'B',
#  '44': 'A',
#  '45': 'C',
#  '46': 'D',
#  '47': 'C',
#  '48': 'D',
#  '49': 'C',
#  '50': 'A',
#  '51': 'C',
#  '52': 'C',
#  '53': 'C',
#  '54': 'C',
#  '55': 'B',
#  '56': 'A',
#  '57': 'A',
#  '58': 'C',
#  '59': 'C',
#  '60': 'B',
#  '61': 'C',
#  '62': 'B',
#  '63': 'C',
#  '64': 'D',
#  '65': 'D',
#  '66': 'B',
#  '67': 'B',
#  '68': 'B',
#  '69': 'D',
#  '70': 'D',
#  '71': 'A',
#  '72': 'A',
#  '73': 'D',
#  '74': 'B',
#  '75': 'B',
#  '76': 'C',
#  '77': 'C',
#  '78': 'C',
#  '79': 'D',
#  '80': 'C',
#  '81': 'B',
#  '82': 'B',
#  '83': 'C',
#  '84': 'D',
#  '85': 'C',
#  '86': 'D',
#  '87': 'A',
#  '88': 'A',
#  '89': 'D',
#  '90': 'C',
#  '91': 'D',
#  '92': 'D',
#  '93': 'A',
#  '94': 'D',
#  '95': 'B',
#  '96': 'A',
#  '97': 'C',
#  '98': 'A',
#  '99': 'A',
#  '100': 'A',
#  '101': 'A',
#  '102': 'A',
#  '103': 'D',
#  '104': 'A',
#  '105': 'D',
#  '106': 'C',
#  '107': 'A',
#  '108': 'C',
#  '109': 'A',
#  '110': 'A',
#  '111': 'C',
#  '112': 'D',
#  '113': 'C',
#  '114': 'C',
#  '115': 'C',
#  '116': 'B',
#  '117': 'C',
#  '118': 'D',
#  '119': 'A',
#  '120': 'B',
#  '121': 'B',
#  '122': 'A',
#  '123': 'B',
#  '124': 'D',
#  '125': 'C',
#  '126': 'C',
#  '127': 'A',
#  '128': 'B',
#  '129': 'A',
#  '130': 'B',
#  '131': 'C',
#  '132': 'C',
#  '133': 'C',
#  '134': 'B',
#  '135': 'C',
#  '136': 'A',
#  '137': 'B',
#  '138': 'C',
#  '139': 'A',
#  '140': 'C',
#  '141': 'D',
#  '142': 'D',
#  '143': 'D',
#  '144': 'C',
#  '145': 'C',
#  '146': 'D',
#  '147': 'A',
#  '148': 'D',
#  '149': 'B',
#  '150': 'A',
#  '151': 'D',
#  '152': 'B',
#  '153': 'B',
#  '154': 'B',
#  '155': 'A',
#  '156': 'B',
#  '157': 'D',
#  '158': 'A',
#  '159': 'A',
#  '160': 'B',
#  '161': 'C',
#  '162': 'A',
#  '163': 'A',
#  '164': 'B',
#  '165': 'C',
#  '166': 'A',
#  '167': 'B',
#  '168': 'A',
#  '169': 'D',
#  '170': 'B',
#  '171': 'C',
#  '172': 'A',
#  '173': 'C',
#  '174': 'A',
#  '175': 'C',
#  '176': 'B',
#  '177': 'A',
#  '178': 'C',
#  '179': 'A',
#  '180': 'C',
#  '181': 'A',
#  '182': 'A',
#  '183': 'D',
#  '184': 'C',
#  '185': 'A',
#  '186': 'B',
#  '187': 'C',
#  '188': 'D',
#  '189': 'C',
#  '190': 'B',
#  '191': 'C',
#  '192': 'D',
#  '193': 'D',
#  '194': 'B',
#  '195': 'C',
#  '196': 'B',
#  '197': 'C',
#  '198': 'D',
#  '199': 'D',
#  '200': 'B'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'The Projex Academy'
        qadata['year'] = 2022
        qadata['type'] = 'PMP Sample Paper with ANSWERS'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
        if matchQN=='200':
            break
        if matchQN !='243':
            qadata['answerKey'] = answer_dict_new[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '1',
#   'question': {'stem': 'Your project sponsor has requested a cost estimate for the project. He would like the cost estimate to be as accurate as possible as this might be his one and only chance to secure the budget for this project due to recent cuts in special projects. You decide:',
#    'choices': [{'label': 'A',
#      'text': 'To use analogous estimating techniques'},
#     {'label': 'B', 'text': 'To use bottom-up estimating techniques'},
#     {'label': 'C', 'text': 'To use top-down estimating techniques'},
#     {'label': 'D', 'text': 'To use expert judgment techniques'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'Your project sponsor has requested a cost estimate for the project. He would like the cost estimate to be as accurate as possible as this might be his one and only chance to secure the budget for this project due to recent cuts in special projects. You decide: To use analogous estimating techniques'},
#    {'label': True,
#     'statement': 'Your project sponsor has requested a cost estimate for the project. He would like the cost estimate to be as accurate as possible as this might be his one and only chance to secure the budget for this project due to recent cuts in special projects. You decide: To use bottom-up estimating techniques'},
#    {'label': False,
#     'statement': 'Your project sponsor has requested a cost estimate for the project. He would like the cost estimate to be as accurate as possible as this might be his one and only chance to secure the budget for this project due to recent cuts in special projects. You decide: To use top-down estimating techniques'},
#    {'label': False,
#     'statement': 'Your project sponsor has requested a cost estimate for the project. He would like the cost estimate to be as accurate as possible as this might be his one and only chance to secure the budget for this project due to recent cuts in special projects. You decide: To use expert judgment techniques'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '2',
#   'question': {'stem': 'You are the project manager for a Social Media Tools company, and your new product needs a database set up for your customers. While installing, several problems occurred and your development team have identified probable causes. Which of the following will identify variables that will have the greatest effect on your project outcomes?',
#    'choices': [{'label': 'A', 'text': 'Design of experiments'},
#     {'label': 'B', 'text': 'Benchmarking'},
#     {'label': 'C', 'text': 'Benefit/cost analysis'},
#     {'label': 'D', 'text': 'Flowcharting'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'You are the project manager for a Social Media Tools company, and your new product needs a database set up for your customers. While installing, several problems occurred and your development team have identified probable causes. Which of the following will identify variables that will have the greatest effect on your project outcomes? Design of experiments'},
#    {'label': False,
#     'statement': 'You are the project manager for a Social Media Tools company, and your new product needs a database set up for your customers. While installing, several problems occurred and your development team have identified probable causes. Which of the following will identify variables that will have the greatest effect on your project outcomes? Benchmarking'},
#    {'label': False,
#     'statement': 'You are the project manager for a Social Media Tools company, and your new product needs a database set up for your customers. While installing, several problems occurred and your development team have identified probable causes. Which of the following will identify variables that will have the greatest effect on your project outcomes? Benefit/cost analysis'},
#    {'label': False,
#     'statement': 'You are the project manager for a Social Media Tools company, and your new product needs a database set up for your customers. While installing, several problems occurred and your development team have identified probable causes. Which of the following will identify variables that will have the greatest effect on your project outcomes? Flowcharting'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '3',
#   'question': {'stem': 'What is critical path?',
#    'choices': [{'label': 'A',
#      'text': 'The shortest path through the network, which represents the longest amount of time in which a project can be completed.'},
#     {'label': 'B', 'text': 'The path with externally controlled resources'},
#     {'label': 'C',
#      'text': 'The longest path through the network, which represents the shortest amount of time in which a project can be completed.'},
#     {'label': 'D',
#      'text': 'The path with the most activities with the longest durations'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'What is critical path? The shortest path through the network, which represents the longest amount of time in which a project can be completed.'},
#    {'label': False,
#     'statement': 'What is critical path? The path with externally controlled resources'},
#    {'label': True,
#     'statement': 'What is critical path? The longest path through the network, which represents the shortest amount of time in which a project can be completed.'},
#    {'label': False,
#     'statement': 'What is critical path? The path with the most activities with the longest durations'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '4',
#   'question': {'stem': 'A recently approved change means that different resources will, be needed for the next month. Who is the role that usually owns the resources that are loaned to the project?',
#    'choices': [{'label': 'A', 'text': 'Owner'},
#     {'label': 'B', 'text': 'Sponsor'},
#     {'label': 'C', 'text': 'Functional Manager'},
#     {'label': 'D', 'text': 'Client'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'A recently approved change means that different resources will, be needed for the next month. Who is the role that usually owns the resources that are loaned to the project? Owner'},
#    {'label': False,
#     'statement': 'A recently approved change means that different resources will, be needed for the next month. Who is the role that usually owns the resources that are loaned to the project? Sponsor'},
#    {'label': True,
#     'statement': 'A recently approved change means that different resources will, be needed for the next month. Who is the role that usually owns the resources that are loaned to the project? Functional Manager'},
#    {'label': False,
#     'statement': 'A recently approved change means that different resources will, be needed for the next month. Who is the role that usually owns the resources that are loaned to the project? Client'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '5',
#   'question': {'stem': 'Your company provides laser light show services for major rock acts, and the manager of Zed Lepelin are planning a reunion tour and have asked for a quotation for a complex light show that will need intensive programming. You decide to outsource this part of the potential contract to a specialist software vendor to minimize the risk to your organization. Which contract type of the following would you choose?',
#    'choices': [{'label': 'A', 'text': 'Fixed price plus incentive -'},
#     {'label': 'B', 'text': 'Cost plus fixed fee'},
#     {'label': 'C', 'text': 'Fixed price'},
#     {'label': 'D', 'text': 'Cost plus incentive'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'Your company provides laser light show services for major rock acts, and the manager of Zed Lepelin are planning a reunion tour and have asked for a quotation for a complex light show that will need intensive programming. You decide to outsource this part of the potential contract to a specialist software vendor to minimize the risk to your organization. Which contract type of the following would you choose? Fixed price plus incentive -'},
#    {'label': False,
#     'statement': 'Your company provides laser light show services for major rock acts, and the manager of Zed Lepelin are planning a reunion tour and have asked for a quotation for a complex light show that will need intensive programming. You decide to outsource this part of the potential contract to a specialist software vendor to minimize the risk to your organization. Which contract type of the following would you choose? Cost plus fixed fee'},
#    {'label': True,
#     'statement': 'Your company provides laser light show services for major rock acts, and the manager of Zed Lepelin are planning a reunion tour and have asked for a quotation for a complex light show that will need intensive programming. You decide to outsource this part of the potential contract to a specialist software vendor to minimize the risk to your organization. Which contract type of the following would you choose? Fixed price'},
#    {'label': False,
#     'statement': 'Your company provides laser light show services for major rock acts, and the manager of Zed Lepelin are planning a reunion tour and have asked for a quotation for a complex light show that will need intensive programming. You decide to outsource this part of the potential contract to a specialist software vendor to minimize the risk to your organization. Which contract type of the following would you choose? Cost plus incentive'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '6',
#   'question': {'stem': 'A Work Authorisation System is needed to',
#    'choices': [{'label': 'A', 'text': 'Control who does each task'},
#     {'label': 'B',
#      'text': 'Ensure work is done by the identified organization at the right time and in the right sequence'},
#     {'label': 'C', 'text': 'Let management know what tasks are planned'},
#     {'label': 'D', 'text': 'As input to the re-planning cycle'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'A Work Authorisation System is needed to Control who does each task'},
#    {'label': True,
#     'statement': 'A Work Authorisation System is needed to Ensure work is done by the identified organization at the right time and in the right sequence'},
#    {'label': False,
#     'statement': 'A Work Authorisation System is needed to Let management know what tasks are planned'},
#    {'label': False,
#     'statement': 'A Work Authorisation System is needed to As input to the re-planning cycle'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '7',
#   'question': {'stem': "An important deadline is approaching that depends on the successful completion of the testing phase of your project. You've detected some software problems and discover that the hardware is not compatible with other network equipment. You take corrective action and exchange the hardware for more compatible equipment. Which of the following is true?",
#    'choices': [{'label': 'A',
#      'text': 'This is not a corrective action as corrective action involves human resources, not project resources.'},
#     {'label': 'B',
#      'text': 'Corrective action is taken here to make sure the future project outcomes are aligned with the project plan.'},
#     {'label': 'C',
#      'text': "Corrective action is not necessary in this case, as the future project outcomes aren't affected."},
#     {'label': 'D',
#      'text': 'Corrective action serves as the change request to authorize exchanging the'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': "An important deadline is approaching that depends on the successful completion of the testing phase of your project. You've detected some software problems and discover that the hardware is not compatible with other network equipment. You take corrective action and exchange the hardware for more compatible equipment. Which of the following is true? This is not a corrective action as corrective action involves human resources, not project resources."},
#    {'label': True,
#     'statement': "An important deadline is approaching that depends on the successful completion of the testing phase of your project. You've detected some software problems and discover that the hardware is not compatible with other network equipment. You take corrective action and exchange the hardware for more compatible equipment. Which of the following is true? Corrective action is taken here to make sure the future project outcomes are aligned with the project plan."},
#    {'label': False,
#     'statement': "An important deadline is approaching that depends on the successful completion of the testing phase of your project. You've detected some software problems and discover that the hardware is not compatible with other network equipment. You take corrective action and exchange the hardware for more compatible equipment. Which of the following is true? Corrective action is not necessary in this case, as the future project outcomes aren't affected."},
#    {'label': False,
#     'statement': "An important deadline is approaching that depends on the successful completion of the testing phase of your project. You've detected some software problems and discover that the hardware is not compatible with other network equipment. You take corrective action and exchange the hardware for more compatible equipment. Which of the following is true? Corrective action serves as the change request to authorize exchanging the"}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '8',
#   'question': {'stem': 'Project managers use which following conflict resolution technique most often:',
#    'choices': [{'label': 'A', 'text': 'Smoothing'},
#     {'label': 'B', 'text': 'Confronting'},
#     {'label': 'C', 'text': 'Norming'},
#     {'label': 'D', 'text': 'Forcing'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'Project managers use which following conflict resolution technique most often: Smoothing'},
#    {'label': True,
#     'statement': 'Project managers use which following conflict resolution technique most often: Confronting'},
#    {'label': False,
#     'statement': 'Project managers use which following conflict resolution technique most often: Norming'},
#    {'label': False,
#     'statement': 'Project managers use which following conflict resolution technique most often: Forcing'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '9',
#   'question': {'stem': 'During the opening rounds of contract negotiation, the other party uses a fait accompli tactic. Which of the following is true?',
#    'choices': [{'label': 'A',
#      'text': 'One party agrees to accept the offer of the other party but secretly knows they will bring the issue back up later.'},
#     {'label': 'B',
#      'text': 'One party claims the issue under discussion was documented and accepted as part of Scope Verification.'},
#     {'label': 'C',
#      'text': "One party claims the issue under discussion has already been decided and can't be changed."},
#     {'label': 'D',
#      'text': 'One party claims to accept the offer of the other party provided a contract change'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'During the opening rounds of contract negotiation, the other party uses a fait accompli tactic. Which of the following is true? One party agrees to accept the offer of the other party but secretly knows they will bring the issue back up later.'},
#    {'label': False,
#     'statement': 'During the opening rounds of contract negotiation, the other party uses a fait accompli tactic. Which of the following is true? One party claims the issue under discussion was documented and accepted as part of Scope Verification.'},
#    {'label': True,
#     'statement': "During the opening rounds of contract negotiation, the other party uses a fait accompli tactic. Which of the following is true? One party claims the issue under discussion has already been decided and can't be changed."},
#    {'label': False,
#     'statement': 'During the opening rounds of contract negotiation, the other party uses a fait accompli tactic. Which of the following is true? One party claims to accept the offer of the other party provided a contract change'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '10',
#   'question': {'stem': 'Projects are initiated in response to:',
#    'choices': [{'label': 'A', 'text': "Stakeholder's pressure"},
#     {'label': 'B', 'text': 'Business needs'},
#     {'label': 'C', 'text': 'Technological obsolescence'},
#     {'label': 'D', 'text': 'All the above'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': "Projects are initiated in response to: Stakeholder's pressure"},
#    {'label': True,
#     'statement': 'Projects are initiated in response to: Business needs'},
#    {'label': False,
#     'statement': 'Projects are initiated in response to: Technological obsolescence'},
#    {'label': False,
#     'statement': 'Projects are initiated in response to: All the above'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '11',
#   'question': {'stem': 'You do not expect the types of variance that have occurred on the project to date to continue. If BAC = 300, ETC = 275, PV = 300, AC = 200, EV = 250, and CPI = 1.25, what is the EAC?',
#    'choices': [{'label': 'A', 'text': '240'},
#     {'label': 'B', 'text': '250'},
#     {'label': 'C', 'text': '475'},
#     {'label': 'D', 'text': '150'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'You do not expect the types of variance that have occurred on the project to date to continue. If BAC = 300, ETC = 275, PV = 300, AC = 200, EV = 250, and CPI = 1.25, what is the EAC? 240'},
#    {'label': True,
#     'statement': 'You do not expect the types of variance that have occurred on the project to date to continue. If BAC = 300, ETC = 275, PV = 300, AC = 200, EV = 250, and CPI = 1.25, what is the EAC? 250'},
#    {'label': False,
#     'statement': 'You do not expect the types of variance that have occurred on the project to date to continue. If BAC = 300, ETC = 275, PV = 300, AC = 200, EV = 250, and CPI = 1.25, what is the EAC? 475'},
#    {'label': False,
#     'statement': 'You do not expect the types of variance that have occurred on the project to date to continue. If BAC = 300, ETC = 275, PV = 300, AC = 200, EV = 250, and CPI = 1.25, what is the EAC? 150'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '12',
#   'question': {'stem': 'Your project has recently experienced change. Some of the agreed upon WBS elements have been changed as a result. What kind of change has occurred?',
#    'choices': [{'label': 'A', 'text': 'Schedule change'},
#     {'label': 'B', 'text': 'Risk response change'},
#     {'label': 'C', 'text': 'Quality change'},
#     {'label': 'D', 'text': 'Scope change'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Your project has recently experienced change. Some of the agreed upon WBS elements have been changed as a result. What kind of change has occurred? Schedule change'},
#    {'label': False,
#     'statement': 'Your project has recently experienced change. Some of the agreed upon WBS elements have been changed as a result. What kind of change has occurred? Risk response change'},
#    {'label': False,
#     'statement': 'Your project has recently experienced change. Some of the agreed upon WBS elements have been changed as a result. What kind of change has occurred? Quality change'},
#    {'label': True,
#     'statement': 'Your project has recently experienced change. Some of the agreed upon WBS elements have been changed as a result. What kind of change has occurred? Scope change'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '13',
#   'question': {'stem': 'You are the project manager for a land and property agency, and you are currently in the monitoring and controlling process of your project. The major buyer (your customer) has asked you to give her an update on how well the project is performing. Which of the following reports are input examples for the Manage Communications process?',
#    'choices': [{'label': 'A',
#      'text': 'Cause and effect and traceability matrix'},
#     {'label': 'B', 'text': 'S-curve, and productivity matrix'},
#     {'label': 'C', 'text': 'S-curve and Delphi charts'},
#     {'label': 'D', 'text': 'Work Performance Reports'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'You are the project manager for a land and property agency, and you are currently in the monitoring and controlling process of your project. The major buyer (your customer) has asked you to give her an update on how well the project is performing. Which of the following reports are input examples for the Manage Communications process? Cause and effect and traceability matrix'},
#    {'label': False,
#     'statement': 'You are the project manager for a land and property agency, and you are currently in the monitoring and controlling process of your project. The major buyer (your customer) has asked you to give her an update on how well the project is performing. Which of the following reports are input examples for the Manage Communications process? S-curve, and productivity matrix'},
#    {'label': False,
#     'statement': 'You are the project manager for a land and property agency, and you are currently in the monitoring and controlling process of your project. The major buyer (your customer) has asked you to give her an update on how well the project is performing. Which of the following reports are input examples for the Manage Communications process? S-curve and Delphi charts'},
#    {'label': True,
#     'statement': 'You are the project manager for a land and property agency, and you are currently in the monitoring and controlling process of your project. The major buyer (your customer) has asked you to give her an update on how well the project is performing. Which of the following reports are input examples for the Manage Communications process? Work Performance Reports'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '14',
#   'question': {'stem': 'All the following are tools for the Close Procurements process except:',
#    'choices': [{'label': 'A', 'text': 'Procurement Negotiations'},
#     {'label': 'B', 'text': 'Records Management System'},
#     {'label': 'C', 'text': 'Procurement Audits'},
#     {'label': 'D', 'text': 'The Project Review'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'All the following are tools for the Close Procurements process except: Procurement Negotiations'},
#    {'label': False,
#     'statement': 'All the following are tools for the Close Procurements process except: Records Management System'},
#    {'label': False,
#     'statement': 'All the following are tools for the Close Procurements process except: Procurement Audits'},
#    {'label': True,
#     'statement': 'All the following are tools for the Close Procurements process except: The Project Review'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '15',
#   'question': {'stem': 'You and your company are both on a contracted bonus upon successful completion of your project. You are currently predicting that as your project nears its end, that you will deliver on time and under budget meaning the bonuses will be reduced. Which of the following options should you do?',
#    'choices': [{'label': 'A',
#      'text': 'Add activities to the project to increase the cost enough to meet the original estimated amount.'},
#     {'label': 'B',
#      'text': "Tell the customer you're adding additional requirements to the project that were originally cut because of cost constraints."},
#     {'label': 'C',
#      'text': 'Upon completion inform the customer that the project has come in under budget.'},
#     {'label': 'D',
#      'text': 'Bill the customer for the full amount of the contract, as this was the original'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'You and your company are both on a contracted bonus upon successful completion of your project. You are currently predicting that as your project nears its end, that you will deliver on time and under budget meaning the bonuses will be reduced. Which of the following options should you do? Add activities to the project to increase the cost enough to meet the original estimated amount.'},
#    {'label': False,
#     'statement': "You and your company are both on a contracted bonus upon successful completion of your project. You are currently predicting that as your project nears its end, that you will deliver on time and under budget meaning the bonuses will be reduced. Which of the following options should you do? Tell the customer you're adding additional requirements to the project that were originally cut because of cost constraints."},
#    {'label': True,
#     'statement': 'You and your company are both on a contracted bonus upon successful completion of your project. You are currently predicting that as your project nears its end, that you will deliver on time and under budget meaning the bonuses will be reduced. Which of the following options should you do? Upon completion inform the customer that the project has come in under budget.'},
#    {'label': False,
#     'statement': 'You and your company are both on a contracted bonus upon successful completion of your project. You are currently predicting that as your project nears its end, that you will deliver on time and under budget meaning the bonuses will be reduced. Which of the following options should you do? Bill the customer for the full amount of the contract, as this was the original'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '16',
#   'question': {'stem': 'In a group of 4 members, an extra member has been added. How many communication channels are there now?',
#    'choices': [{'label': 'A', 'text': '5'},
#     {'label': 'B', 'text': '3'},
#     {'label': 'C', 'text': '10'},
#     {'label': 'D', 'text': '20'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'In a group of 4 members, an extra member has been added. How many communication channels are there now? 5'},
#    {'label': False,
#     'statement': 'In a group of 4 members, an extra member has been added. How many communication channels are there now? 3'},
#    {'label': True,
#     'statement': 'In a group of 4 members, an extra member has been added. How many communication channels are there now? 10'},
#    {'label': False,
#     'statement': 'In a group of 4 members, an extra member has been added. How many communication channels are there now? 20'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '17',
#   'question': {'stem': 'Which of the following methods is least likely to be used for explaining project planning guidelines to the team?',
#    'choices': [{'label': 'A', 'text': 'Project Office Memo'},
#     {'label': 'B', 'text': 'Project office directive'},
#     {'label': 'C', 'text': 'Project team meeting'},
#     {'label': 'D', 'text': 'Formal project report'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Which of the following methods is least likely to be used for explaining project planning guidelines to the team? Project Office Memo'},
#    {'label': False,
#     'statement': 'Which of the following methods is least likely to be used for explaining project planning guidelines to the team? Project office directive'},
#    {'label': False,
#     'statement': 'Which of the following methods is least likely to be used for explaining project planning guidelines to the team? Project team meeting'},
#    {'label': True,
#     'statement': 'Which of the following methods is least likely to be used for explaining project planning guidelines to the team? Formal project report'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '18',
#   'question': {'stem': 'You work as a project manager for the local telephone company and your project is to electronically compile the latest 600-page telephone directory so that your project customer can distribute their free business listings catalogue. Some of your listings contain confidential information and those clients who do not wish to advertise their telephone numbers. The customer of your project has contacted you directly asking for such clients details to be included so that he can sell this information as a premium service. Which following option is the only choice you should make?',
#    'choices': [{'label': 'A', 'text': 'Report her to the management team'},
#     {'label': 'B',
#      'text': 'Refuse to comply with the request, citing conflict of interest and violation of confidential company data.'},
#     {'label': 'C',
#      'text': "Look up the information she's requested. Since the data is considered part of the project, there is no conflict of interest."},
#     {'label': 'D',
#      'text': 'You believe that installed telephone information and details are public'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'You work as a project manager for the local telephone company and your project is to electronically compile the latest 600-page telephone directory so that your project customer can distribute their free business listings catalogue. Some of your listings contain confidential information and those clients who do not wish to advertise their telephone numbers. The customer of your project has contacted you directly asking for such clients details to be included so that he can sell this information as a premium service. Which following option is the only choice you should make? Report her to the management team'},
#    {'label': True,
#     'statement': 'You work as a project manager for the local telephone company and your project is to electronically compile the latest 600-page telephone directory so that your project customer can distribute their free business listings catalogue. Some of your listings contain confidential information and those clients who do not wish to advertise their telephone numbers. The customer of your project has contacted you directly asking for such clients details to be included so that he can sell this information as a premium service. Which following option is the only choice you should make? Refuse to comply with the request, citing conflict of interest and violation of confidential company data.'},
#    {'label': False,
#     'statement': "You work as a project manager for the local telephone company and your project is to electronically compile the latest 600-page telephone directory so that your project customer can distribute their free business listings catalogue. Some of your listings contain confidential information and those clients who do not wish to advertise their telephone numbers. The customer of your project has contacted you directly asking for such clients details to be included so that he can sell this information as a premium service. Which following option is the only choice you should make? Look up the information she's requested. Since the data is considered part of the project, there is no conflict of interest."},
#    {'label': False,
#     'statement': 'You work as a project manager for the local telephone company and your project is to electronically compile the latest 600-page telephone directory so that your project customer can distribute their free business listings catalogue. Some of your listings contain confidential information and those clients who do not wish to advertise their telephone numbers. The customer of your project has contacted you directly asking for such clients details to be included so that he can sell this information as a premium service. Which following option is the only choice you should make? You believe that installed telephone information and details are public'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '19',
#   'question': {'stem': 'Which is not a technique used for the Estimate Costs process?',
#    'choices': [{'label': 'A', 'text': 'Analogous Estimating'},
#     {'label': 'B', 'text': 'Bottom-up Estimating'},
#     {'label': 'C', 'text': 'Parametric Estimating'},
#     {'label': 'D', 'text': 'Resource Leveling'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Which is not a technique used for the Estimate Costs process? Analogous Estimating'},
#    {'label': False,
#     'statement': 'Which is not a technique used for the Estimate Costs process? Bottom-up Estimating'},
#    {'label': False,
#     'statement': 'Which is not a technique used for the Estimate Costs process? Parametric Estimating'},
#    {'label': True,
#     'statement': 'Which is not a technique used for the Estimate Costs process? Resource Leveling'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '20',
#   'question': {'stem': 'A project manager has increased project costs by $75,000, but completed the project six weeks earlier than planned. What tool is best described here?',
#    'choices': [{'label': 'A', 'text': 'Resource leveling'},
#     {'label': 'B', 'text': 'Duration compression'},
#     {'label': 'C', 'text': 'Crashing'},
#     {'label': 'D', 'text': 'Fast tracking'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'A project manager has increased project costs by $75,000, but completed the project six weeks earlier than planned. What tool is best described here? Resource leveling'},
#    {'label': False,
#     'statement': 'A project manager has increased project costs by $75,000, but completed the project six weeks earlier than planned. What tool is best described here? Duration compression'},
#    {'label': True,
#     'statement': 'A project manager has increased project costs by $75,000, but completed the project six weeks earlier than planned. What tool is best described here? Crashing'},
#    {'label': False,
#     'statement': 'A project manager has increased project costs by $75,000, but completed the project six weeks earlier than planned. What tool is best described here? Fast tracking'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '21',
#   'question': {'stem': 'You are the project manager for PerkUp a sports energy drink which you are promoting in a Middle Eastern country which currently already has a competing well-established energy enhancing beverage. You have yet to inform your current company that you are going to go to work for the competitor, what is the most appropriate response?',
#    'choices': [{'label': 'A',
#      'text': 'You decline to participate in the initial meetings with the foreign business partners, due to conflict of interest.'},
#     {'label': 'B',
#      'text': "You've not yet received an official offer from the competing company for your new job opportunity, so you choose to participate in the initial meetings with the foreign business partners."},
#     {'label': 'C',
#      'text': 'You decide to participate in the initial meetings with the foreign business partners because any information you gain now will help you when you make the move to the new company.'},
#     {'label': 'D',
#      'text': "You inform the foreign business partners that you're going to be working with a new"}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'You are the project manager for PerkUp a sports energy drink which you are promoting in a Middle Eastern country which currently already has a competing well-established energy enhancing beverage. You have yet to inform your current company that you are going to go to work for the competitor, what is the most appropriate response? You decline to participate in the initial meetings with the foreign business partners, due to conflict of interest.'},
#    {'label': False,
#     'statement': "You are the project manager for PerkUp a sports energy drink which you are promoting in a Middle Eastern country which currently already has a competing well-established energy enhancing beverage. You have yet to inform your current company that you are going to go to work for the competitor, what is the most appropriate response? You've not yet received an official offer from the competing company for your new job opportunity, so you choose to participate in the initial meetings with the foreign business partners."},
#    {'label': False,
#     'statement': 'You are the project manager for PerkUp a sports energy drink which you are promoting in a Middle Eastern country which currently already has a competing well-established energy enhancing beverage. You have yet to inform your current company that you are going to go to work for the competitor, what is the most appropriate response? You decide to participate in the initial meetings with the foreign business partners because any information you gain now will help you when you make the move to the new company.'},
#    {'label': False,
#     'statement': "You are the project manager for PerkUp a sports energy drink which you are promoting in a Middle Eastern country which currently already has a competing well-established energy enhancing beverage. You have yet to inform your current company that you are going to go to work for the competitor, what is the most appropriate response? You inform the foreign business partners that you're going to be working with a new"}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '22',
#   'question': {'stem': 'Your project team is made up of six full-time employees and three contractors. This is the first time they have all worked together. How many lines of communication exist among the project team members?',
#    'choices': [{'label': 'A', 'text': '36'},
#     {'label': 'B', 'text': '41'},
#     {'label': 'C', 'text': '18'},
#     {'label': 'D', 'text': '34'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'Your project team is made up of six full-time employees and three contractors. This is the first time they have all worked together. How many lines of communication exist among the project team members? 36'},
#    {'label': False,
#     'statement': 'Your project team is made up of six full-time employees and three contractors. This is the first time they have all worked together. How many lines of communication exist among the project team members? 41'},
#    {'label': False,
#     'statement': 'Your project team is made up of six full-time employees and three contractors. This is the first time they have all worked together. How many lines of communication exist among the project team members? 18'},
#    {'label': False,
#     'statement': 'Your project team is made up of six full-time employees and three contractors. This is the first time they have all worked together. How many lines of communication exist among the project team members? 34'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '23',
#   'question': {'stem': 'You are a project manager working for a pop and rock festival organizer in the south of the UK and are nearly complete in the festival preparation, when you get a weather forecast for next weeks concert that rain is expected. You are currently putting response plans in place just in case it rains during the concert. This is an example of which Risk Response Planning tool and technique?',
#    'choices': [{'label': 'A', 'text': 'Passive acceptance'},
#     {'label': 'B', 'text': 'Contingency planning'},
#     {'label': 'C', 'text': 'Avoidance'},
#     {'label': 'D', 'text': 'Transference'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'You are a project manager working for a pop and rock festival organizer in the south of the UK and are nearly complete in the festival preparation, when you get a weather forecast for next weeks concert that rain is expected. You are currently putting response plans in place just in case it rains during the concert. This is an example of which Risk Response Planning tool and technique? Passive acceptance'},
#    {'label': True,
#     'statement': 'You are a project manager working for a pop and rock festival organizer in the south of the UK and are nearly complete in the festival preparation, when you get a weather forecast for next weeks concert that rain is expected. You are currently putting response plans in place just in case it rains during the concert. This is an example of which Risk Response Planning tool and technique? Contingency planning'},
#    {'label': False,
#     'statement': 'You are a project manager working for a pop and rock festival organizer in the south of the UK and are nearly complete in the festival preparation, when you get a weather forecast for next weeks concert that rain is expected. You are currently putting response plans in place just in case it rains during the concert. This is an example of which Risk Response Planning tool and technique? Avoidance'},
#    {'label': False,
#     'statement': 'You are a project manager working for a pop and rock festival organizer in the south of the UK and are nearly complete in the festival preparation, when you get a weather forecast for next weeks concert that rain is expected. You are currently putting response plans in place just in case it rains during the concert. This is an example of which Risk Response Planning tool and technique? Transference'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '24',
#   'question': {'stem': 'The Delphi Method is best suited for:',
#    'choices': [{'label': 'A', 'text': 'Decision-making'},
#     {'label': 'B', 'text': 'Cost Control'},
#     {'label': 'C', 'text': 'Overhead rate estimating'},
#     {'label': 'D', 'text': 'Team discussions'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'The Delphi Method is best suited for: Decision-making'},
#    {'label': False,
#     'statement': 'The Delphi Method is best suited for: Cost Control'},
#    {'label': False,
#     'statement': 'The Delphi Method is best suited for: Overhead rate estimating'},
#    {'label': False,
#     'statement': 'The Delphi Method is best suited for: Team discussions'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '25',
#   'question': {'stem': "You are ready to perform the Sequence Activities process for your project. To make your job easier, you're going to use a software tool to help you draw a network diagram. Most software programs use this technique. You know all of the following are true apart from:",
#    'choices': [{'label': 'A',
#      'text': 'It shows the activities on arrows and connects them to dependencies usually depicted as circles.'},
#     {'label': 'B', 'text': 'It is also called AON.'},
#     {'label': 'C',
#      'text': 'It shows the activities in boxes with arrows connecting the dependent activities.'},
#     {'label': 'D',
#      'text': 'It uses four types of dependency relationships of which finish to start is one'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': "You are ready to perform the Sequence Activities process for your project. To make your job easier, you're going to use a software tool to help you draw a network diagram. Most software programs use this technique. You know all of the following are true apart from: It shows the activities on arrows and connects them to dependencies usually depicted as circles."},
#    {'label': False,
#     'statement': "You are ready to perform the Sequence Activities process for your project. To make your job easier, you're going to use a software tool to help you draw a network diagram. Most software programs use this technique. You know all of the following are true apart from: It is also called AON."},
#    {'label': False,
#     'statement': "You are ready to perform the Sequence Activities process for your project. To make your job easier, you're going to use a software tool to help you draw a network diagram. Most software programs use this technique. You know all of the following are true apart from: It shows the activities in boxes with arrows connecting the dependent activities."},
#    {'label': False,
#     'statement': "You are ready to perform the Sequence Activities process for your project. To make your job easier, you're going to use a software tool to help you draw a network diagram. Most software programs use this technique. You know all of the following are true apart from: It uses four types of dependency relationships of which finish to start is one"}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '26',
#   'question': {'stem': "You have just accepted a new project management assignment in a foreign country. You've requested a business analyst and two other project team members from the country the customer resides in to, participate on your team. The remaining team members are from your country. You know that the best way to ensure the project team doesn't get bogged down in cultural differences and hold up project progress is to:",
#    'choices': [{'label': 'A',
#      'text': 'Perform team-building exercises using video conferencing to allow team members to get to know each other and get to the performing stage of team development as soon as possible.'},
#     {'label': 'B',
#      'text': 'Provide diversity training for all the team members to make them aware of cultural differences and teach them to function effectively as a team despite these differences'},
#     {'label': 'C',
#      'text': 'Establish your role as project manager as the first order of business and require compliance to company policies,'},
#     {'label': 'D',
#      'text': "Require project team members to read and sign the organization's diversity"}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': "You have just accepted a new project management assignment in a foreign country. You've requested a business analyst and two other project team members from the country the customer resides in to, participate on your team. The remaining team members are from your country. You know that the best way to ensure the project team doesn't get bogged down in cultural differences and hold up project progress is to: Perform team-building exercises using video conferencing to allow team members to get to know each other and get to the performing stage of team development as soon as possible."},
#    {'label': True,
# ...
#    {'label': False,
#     'statement': 'You are working on a project to develop a new website for your company. You are monitoring results of the project to determine if they comply with standards set out during the Planning process. You are also taking steps to eliminate unsatisfactory results. This might mean rework in some cases. Which process are you in? Scope change control'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '191',
#   'question': {'stem': 'You are the project manager for Laser Sight Corp who provides the arms industry with software target capture systems. You have just completed a project, and are performing earned value analysis, trend analysis, and performance reviews. Which of the following is true?',
#    'choices': [{'label': 'A',
#      'text': 'This is performance measurement documentation, which is an input to the Close Procurements process.'},
#     {'label': 'B',
#      'text': 'This is performance measurement documentation, which is an input to the Close Administration process.'},
#     {'label': 'C',
#      'text': 'These are performance reporting tools and techniques of Close Project or Phase'},
#     {'label': 'D',
#      'text': 'These are performance reporting tools and techniques of the Contract'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'You are the project manager for Laser Sight Corp who provides the arms industry with software target capture systems. You have just completed a project, and are performing earned value analysis, trend analysis, and performance reviews. Which of the following is true? This is performance measurement documentation, which is an input to the Close Procurements process.'},
#    {'label': False,
#     'statement': 'You are the project manager for Laser Sight Corp who provides the arms industry with software target capture systems. You have just completed a project, and are performing earned value analysis, trend analysis, and performance reviews. Which of the following is true? This is performance measurement documentation, which is an input to the Close Administration process.'},
#    {'label': True,
#     'statement': 'You are the project manager for Laser Sight Corp who provides the arms industry with software target capture systems. You have just completed a project, and are performing earned value analysis, trend analysis, and performance reviews. Which of the following is true? These are performance reporting tools and techniques of Close Project or Phase'},
#    {'label': False,
#     'statement': 'You are the project manager for Laser Sight Corp who provides the arms industry with software target capture systems. You have just completed a project, and are performing earned value analysis, trend analysis, and performance reviews. Which of the following is true? These are performance reporting tools and techniques of the Contract'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '192',
#   'question': {'stem': 'You are a project manager working on contract with a company in a foreign country. At the project kick-off meeting, you are given an expensive-looking gift. The person who presented this to your said that it is customary in their country to give their business partners gifts. What is the most appropriate response?',
#    'choices': [{'label': 'A',
#      'text': 'Thank them and decline. Explain that this is considered personal gain, which is unacceptable in your country.'},
#     {'label': 'B',
#      'text': 'Thank them and accept as there is no conflict of interest or integrity issue at stake.'},
#     {'label': 'C',
#      'text': 'Thank them and decline. Explain that this is considered a conflict of interest, which is unacceptable in your country.'},
#     {'label': 'D',
#      'text': 'Thank them and accept since you know that it would be considered offensive'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'You are a project manager working on contract with a company in a foreign country. At the project kick-off meeting, you are given an expensive-looking gift. The person who presented this to your said that it is customary in their country to give their business partners gifts. What is the most appropriate response? Thank them and decline. Explain that this is considered personal gain, which is unacceptable in your country.'},
#    {'label': False,
#     'statement': 'You are a project manager working on contract with a company in a foreign country. At the project kick-off meeting, you are given an expensive-looking gift. The person who presented this to your said that it is customary in their country to give their business partners gifts. What is the most appropriate response? Thank them and accept as there is no conflict of interest or integrity issue at stake.'},
#    {'label': False,
#     'statement': 'You are a project manager working on contract with a company in a foreign country. At the project kick-off meeting, you are given an expensive-looking gift. The person who presented this to your said that it is customary in their country to give their business partners gifts. What is the most appropriate response? Thank them and decline. Explain that this is considered a conflict of interest, which is unacceptable in your country.'},
#    {'label': True,
#     'statement': 'You are a project manager working on contract with a company in a foreign country. At the project kick-off meeting, you are given an expensive-looking gift. The person who presented this to your said that it is customary in their country to give their business partners gifts. What is the most appropriate response? Thank them and accept since you know that it would be considered offensive'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '193',
#   'question': {'stem': 'All the following are true regarding the Execution processes except:',
#    'choices': [{'label': 'A', 'text': 'Executing has one core process.'},
#     {'label': 'B', 'text': 'Most the project budget is spent here.'},
#     {'label': 'C', 'text': 'The greatest conflicts are schedule conflicts.'},
#     {'label': 'D',
#      'text': 'Project performance is measured to identify variances'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'All the following are true regarding the Execution processes except: Executing has one core process.'},
#    {'label': False,
#     'statement': 'All the following are true regarding the Execution processes except: Most the project budget is spent here.'},
#    {'label': False,
#     'statement': 'All the following are true regarding the Execution processes except: The greatest conflicts are schedule conflicts.'},
#    {'label': True,
#     'statement': 'All the following are true regarding the Execution processes except: Project performance is measured to identify variances'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '194',
#   'question': {'stem': 'Project managers have the greatest amount of authority in which kind of organizational structure?',
#    'choices': [{'label': 'A', 'text': 'Functional'},
#     {'label': 'B', 'text': 'Projectized'},
#     {'label': 'C', 'text': 'Weak Matrix'},
#     {'label': 'D', 'text': 'Balanced Matrix'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'Project managers have the greatest amount of authority in which kind of organizational structure? Functional'},
#    {'label': True,
#     'statement': 'Project managers have the greatest amount of authority in which kind of organizational structure? Projectized'},
#    {'label': False,
#     'statement': 'Project managers have the greatest amount of authority in which kind of organizational structure? Weak Matrix'},
#    {'label': False,
#     'statement': 'Project managers have the greatest amount of authority in which kind of organizational structure? Balanced Matrix'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '195',
#   'question': {'stem': 'Which of the following processes involves receiving bids and proposals and applies evaluation criteria to the proposals to rank order the sequence of award?',
#    'choices': [{'label': 'A', 'text': 'Contract Administration'},
#     {'label': 'B', 'text': 'Procurement'},
#     {'label': 'C', 'text': 'Conduct Procurements'},
#     {'label': 'D', 'text': 'Solicitation'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'Which of the following processes involves receiving bids and proposals and applies evaluation criteria to the proposals to rank order the sequence of award? Contract Administration'},
#    {'label': False,
#     'statement': 'Which of the following processes involves receiving bids and proposals and applies evaluation criteria to the proposals to rank order the sequence of award? Procurement'},
#    {'label': True,
#     'statement': 'Which of the following processes involves receiving bids and proposals and applies evaluation criteria to the proposals to rank order the sequence of award? Conduct Procurements'},
#    {'label': False,
#     'statement': 'Which of the following processes involves receiving bids and proposals and applies evaluation criteria to the proposals to rank order the sequence of award? Solicitation'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '196',
#   'question': {'stem': 'Which of the following contracts should you use for projects that have a degree of uncertainty and require a large investment early in the project life cycle?',
#    'choices': [{'label': 'A', 'text': 'Fixed Price'},
#     {'label': 'B', 'text': 'Cost reimbursable'},
#     {'label': 'C', 'text': 'Lump sum'},
#     {'label': 'D', 'text': 'Unit price'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
#     'statement': 'Which of the following contracts should you use for projects that have a degree of uncertainty and require a large investment early in the project life cycle? Fixed Price'},
#    {'label': True,
#     'statement': 'Which of the following contracts should you use for projects that have a degree of uncertainty and require a large investment early in the project life cycle? Cost reimbursable'},
#    {'label': False,
#     'statement': 'Which of the following contracts should you use for projects that have a degree of uncertainty and require a large investment early in the project life cycle? Lump sum'},
#    {'label': False,
#     'statement': 'Which of the following contracts should you use for projects that have a degree of uncertainty and require a large investment early in the project life cycle? Unit price'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '197',
#   'question': {'stem': 'What type of organization experiences the least amount of stress during project closeout?',
#    'choices': [{'label': 'A', 'text': 'Projectized'},
#     {'label': 'B', 'text': 'Functional'},
#     {'label': 'C', 'text': 'Weak matrix'},
#     {'label': 'D', 'text': 'Strong matrix'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'What type of organization experiences the least amount of stress during project closeout? Projectized'},
#    {'label': False,
#     'statement': 'What type of organization experiences the least amount of stress during project closeout? Functional'},
#    {'label': True,
#     'statement': 'What type of organization experiences the least amount of stress during project closeout? Weak matrix'},
#    {'label': False,
#     'statement': 'What type of organization experiences the least amount of stress during project closeout? Strong matrix'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '198',
#   'question': {'stem': 'You work for a highly-specialized computer graphics and animation company and provides these services to small independent film product companies. Your company is taking advantage of the progress that has been made recently with human and graphics live interaction software to create a new animation products. Initial projections show that market demand is very high for this product. This project came about because of which of the following?',
#    'choices': [{'label': 'A', 'text': 'Marketing demand'},
#     {'label': 'B', 'text': 'Customer request'},
#     {'label': 'C', 'text': 'Business need'},
#     {'label': 'D', 'text': 'Technological advance'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'You work for a highly-specialized computer graphics and animation company and provides these services to small independent film product companies. Your company is taking advantage of the progress that has been made recently with human and graphics live interaction software to create a new animation products. Initial projections show that market demand is very high for this product. This project came about because of which of the following? Marketing demand'},
#    {'label': False,
#     'statement': 'You work for a highly-specialized computer graphics and animation company and provides these services to small independent film product companies. Your company is taking advantage of the progress that has been made recently with human and graphics live interaction software to create a new animation products. Initial projections show that market demand is very high for this product. This project came about because of which of the following? Customer request'},
#    {'label': False,
#     'statement': 'You work for a highly-specialized computer graphics and animation company and provides these services to small independent film product companies. Your company is taking advantage of the progress that has been made recently with human and graphics live interaction software to create a new animation products. Initial projections show that market demand is very high for this product. This project came about because of which of the following? Business need'},
#    {'label': True,
#     'statement': 'You work for a highly-specialized computer graphics and animation company and provides these services to small independent film product companies. Your company is taking advantage of the progress that has been made recently with human and graphics live interaction software to create a new animation products. Initial projections show that market demand is very high for this product. This project came about because of which of the following? Technological advance'}]},
#  {'source': 'The Projex Academy',
#   'year': 2022,
#   'type': 'PMP Sample Paper with ANSWERS',
#   'qid': '199',
#   'question': {'stem': 'Which of the following is true regarding IRR?',
#    'choices': [{'label': 'A',
#      'text': 'IRR assumes reinvestment at the cost of capital.'},
#     {'label': 'B',
#      'text': 'IRR is the discount rate when NPV is greater than zero.'},
#     {'label': 'C', 'text': 'IRR is a constrained optimization method.'},
#     {'label': 'D',
#      'text': 'IRR is the discount rate when NPV is equal to zero'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Which of the following is true regarding IRR? IRR assumes reinvestment at the cost of capital.'},
#    {'label': False,
#     'statement': 'Which of the following is true regarding IRR? IRR is the discount rate when NPV is greater than zero.'},
#    {'label': False,
#     'statement': 'Which of the following is true regarding IRR? IRR is a constrained optimization method.'},
#    {'label': True,
#     'statement': 'Which of the following is true regarding IRR? IRR is the discount rate when NPV is equal to zero'}]}]

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')
