# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set11_statements.jsonl'

# %%
pages_to_extract = list(range(3, 5))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)-([A-D])'

answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value for key, value in answer}

print(answer_dict)
# Out:
# {'1': 'A', '2': 'D', '3': 'D', '4': 'C', '5': 'B', '6': 'A', '7': 'B', '8': 'B', '9': 'A', '10': 'A'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part1'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part1',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Your developer has provided u with an estimate based on the cost per line of code. What type of estimate did the developer use to provide this information?',
#    'choices': [{'label': 'A', 'text': 'Parametric estimating.'},
#     {'label': 'B', 'text': 'Bottom-up- estimating.'},
#     {'label': 'C', 'text': 'Analogues estimating.'},
#     {'label': 'D', 'text': 'PERTestmating .'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'Your developer has provided u with an estimate based on the cost per line of code. What type of estimate did the developer use to provide this information? Parametric estimating.'},
#    {'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set12_statements.jsonl'

# %%
pages_to_extract = list(range(5, 7))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. Should historical information be used during resource planning?
# A. no, since there is rarely any correlation between resource expections on one project when
# compared to another.
# B. Yes, as historical information is available can provide insight into what type of resources were
# required on previous projects of similar nature.
# C. No, since historical information is usally misleading,given the cost of resources have
# undoubedtly changed since the complition of the prior project.
# D.Yes ,since historical information can be easily adjusted to accurately determined current project
# costs.
# 2. Analogus estimating is a :
# A.”bottum-up” estimating technique.
# B.”drop-down” estimating technique.
# C. more costly and more accuratelyestimating technique.
# D. technique used when you have no subject matter experts available.
# 3. Cost estimates:
# A. are usally presented at a detailed level.
# B. can be presented in summary of detail.
# C. are summarized for senior management.
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)-([A-D])'

answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value for key, value in answer}

print(answer_dict)
# Out:
# {'1': 'B', '2': 'B', '3': 'B', '4': 'B', '5': 'B', '6': 'A', '7': 'B', '8': 'A', '9': 'A', '10': 'A'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 2 Part1'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 2 Part1',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Should historical information be used during resource planning?',
#    'choices': [{'label': 'A',
#      'text': 'no, since there is rarely any correlation between resource expections on one project when compared to another.'},
#     {'label': 'B',
#      'text': 'Yes, as historical information is available can provide insight into what type of resources were required on previous projects of similar nature.'},
#     {'label': 'C',
#      'text': 'No, since historical information is usally misleading,given the cost of resources have undoubedtly changed since the complition of the prior project.'},
#     {'label': 'D',
#      'text': 'Yes ,since historical information can be easily adjusted to accurately determined current project'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set13_statements.jsonl'

# %%
pages_to_extract = list(range(7, 11))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. What is the Delphi technique?
# A. A simulation technique.
# B. A mathematical analysis.
# C. A constrained optimization method.
# D. A consensuas technique.
# 2.What is the process of splitting a deliverable into smaller more manageable parts called?
# A. Scope definition.
# B. Decomposition.
# C. Activity definition.
# D.Activity lists.
# 3.The WBS helps the team of FOCUS!It is an excellent tool for communications and the
# basic for developing realistic estimates.You can best describe a WBS as a tool for the
# tracking of the:
# A. the schedule
# B .assigned resources
# C. project costs.
# D. project scope.
# 4.The WBS is
# A. a description of the product component and subcomponents.
# B. a breakdown of the project reporting structure.
# C. a structure that defines the scope baseline for the project.
# D. a structure that defines work assignments by organizations.
# 5.You and several of your key team leader are really struggling with estimating the overall
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

# %%
answer_text="1. D 11. C 21. C\n2. A 12. D 22. C\n3. D 13. D 23. A\n4. C 14. A 24. D\n5. A 15. A 25. C\n6. C 16. A\n7. D 17. C\n8. A 18. D\n9. C 19. C\n10. D 20. C"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1. D 11. C 21. C 2. A 12. D 22. C 3. D 13. D 23. A 4. C 14. A 24. D 5. A 15. A 25. C 6. C 16. A 7. D 17. C 8. A 18. D 9. C 19. C 10. D 20. C

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom),2):
    qn=pom[i].replace('.','')
    qa=pom[i+1]
    answer_dict[qn]=qa
#answer_dict

# %%
answer_dict
# Out:
# {'1': 'D',
#  '11': 'C',
#  '21': 'C',
#  '2': 'A',
#  '12': 'D',
#  '22': 'C',
#  '3': 'D',
#  '13': 'D',
#  '23': 'A',
#  '4': 'C',
#  '14': 'A',
#  '24': 'D',
#  '5': 'A',
#  '15': 'A',
#  '25': 'C',
#  '6': 'C',
#  '16': 'A',
#  '7': 'D',
#  '17': 'C',
#  '8': 'A',
#  '18': 'D',
#  '9': 'C',
#  '19': 'C',
#  '10': 'D',
#  '20': 'C'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part3'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN=='17':
            break
        qadata['answerKey'] = answer_dict.get(matchQN)
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part3',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'What is the Delphi technique?',
#    'choices': [{'label': 'A', 'text': 'A simulation technique.'},
#     {'label': 'B', 'text': 'A mathematical analysis.'},
#     {'label': 'C', 'text': 'A constrained optimization method.'},
#     {'label': 'D', 'text': 'A consensuas technique.'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'What is the Delphi technique? A simulation technique.'},
#    {'label': False,
#     'statement': 'What is the Delphi technique? A mathematical analysis.'},
#    {'label': False,
#     'statement': 'What is the Delphi technique? A constrained optimization method.'},
#    {'label': True,
#     'statement': 'What is the Delphi technique? A consensuas technique.'}]},
#  {'source': 'PMP Exam Question bank Set 1 Part3',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '6',
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set14_statements.jsonl'

# %%
pages_to_extract = list(range(11, 13))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. The WBS can be used for which of the followings?
# A) Communicating with the customers
# B) Showing calendar dates for each task
# C) Showing the functional manager for each team member
# D) Showing the business need for the project
# 2. Scope Verification is
# A) Performed at the end of project planning
# B) Essentially same as quality control
# C) Primarily concerned with acceptance of the work results
# D) Primarily concerned with correctness of the work results
# 3. The process of creating a WBS results in
# A) A project schedule
# B) Team buy-in
# C) A project completion date
# D) A list of risks
# 4. Which of the following DOES NOT describe how far each element in WBS should be broken
# down
# A) Can be completed in under 80 hours.
# B) Can not be logically subdivided further
# C) Is done by one person
# D) Can be realistically estimated
# 5. The outputs of scope change control are
# A) Scope statement, lessons learnt and inspection
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)


qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\)"
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\)([\S\s]*?)\nB\)"
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\)([\S\s]*?)\nC\)"
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\)([\S\s]*?)\nD\)"
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\)([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\.\s+([A-D])'
answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value for key, value in answer}
answer_dict
# Out:
# {'9': 'C',
#  '1': 'A',
#  '2': 'C',
#  '3': 'B',
#  '4': 'C',
#  '5': 'C',
#  '6': 'A',
#  '7': 'A',
#  '8': 'B',
#  '10': 'D'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 4 Part1'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 4 Part1',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'The WBS can be used for which of the followings?',
#    'choices': [{'label': 'A', 'text': 'Communicating with the customers'},
#     {'label': 'B', 'text': 'Showing calendar dates for each task'},
#     {'label': 'C',
#      'text': 'Showing the functional manager for each team member'},
#     {'label': 'D', 'text': 'Showing the business need for the project'}]},
#   'answerKey': 'A',
#   'statements': [{'label': True,
#     'statement': 'The WBS can be used for which of the followings? Communicating with the customers'},
#    {'label': False,
#     'statement': 'The WBS can be used for which of the followings? Showing calendar dates for each task'},
#    {'label': False,
#     'statement': 'The WBS can be used for which of the followings? Showing the functional manager for each team member'},
#    {'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set15_statements.jsonl'

# %%
pages_to_extract = list(range(13, 15))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. A Project Charter includes
# A) Precedence diagramming methods
# B) Task estimates
# C) Detailed resource estimates
# D) The business need for the project
# 2. The customer wants to make a major change in the project scope when project is mostly
# complete. The project manager should.
# E) Make the change
# F) Inform the customer of the impact of the change
# G) Refuse the change
# H) Complain to management
# 3. The key reason to use a WBS is to
# E) Organize the work
# F) Prevent work from slipping through the cracks
# G) Provide a basis for estimating the project
# H) All of the above
# 4. What does having a project charter do for the project managers?
# A) Describes the details of what needs to be done
# B) Describes the names of all team members
# C) Gives the project manager authority
# D) Describes the project's history
# 5. The subdivision of project deliverables into smaller components is called
# A) Concept definition
# B) Flow charting
# C) Scope definition
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)


qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\)"
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\)([\S\s]*?)\nB\)"
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\)([\S\s]*?)\nC\)"
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\)([\S\s]*?)\nD\)"
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\)([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\.\s+([A-D])'
answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value for key, value in answer}
answer_dict
# Out:
# {'1': 'D',
#  '8': 'B',
#  '11': 'C',
#  '2': 'B',
#  '3': 'D',
#  '4': 'C',
#  '5': 'C',
#  '6': 'A',
#  '7': 'B',
#  '9': 'C',
#  '10': 'C'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part5'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part5',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'A Project Charter includes',
#    'choices': [{'label': 'A', 'text': 'Precedence diagramming methods'},
#     {'label': 'B', 'text': 'Task estimates'},
#     {'label': 'C', 'text': 'Detailed resource estimates'},
#     {'label': 'D', 'text': 'The business need for the project'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'A Project Charter includes Precedence diagramming methods'},
#    {'label': False, 'statement': 'A Project Charter includes Task estimates'},
#    {'label': False,
#     'statement': 'A Project Charter includes Detailed resource estimates'},
#    {'label': True,
#     'statement': 'A Project Charter includes The business need for the project'}]},
#  {'source': 'PMP Exam Question bank Set 1 Part5',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '4',
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set16_statements.jsonl'

# %%
pages_to_extract = list(range(15, 17))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. Which of the following is not a major process of Project Procurement Management?
# a) Solicitation Planning
# b) Source Selection
# c) Contract Administration
# d) Information Distribution
# 2. The process of identifying which project needs can be best met by procuring products or
# services outside the project organization is called ________________
# a) Needs Identification
# b) Procurement Planning
# c) Requirement Analysis
# d) None of the above
# 3. The ‘Product Description’ is generally broader than a ‘Statement of Work’. This statement
# a) Is True
# b) Is False
# c) Is Ambiguous
# 4. A contract that involves payment to the seller for its actual costs is called a
# a) Fixed Price Contract
# b) Cost Reimbursable Contract
# c) Unit Price Contract
# d) Partnership
# 5. Which of the following is/are input(s) for Solicitation Planning
# a) Procurement Management Plan
# b) Statement(s) of Work
# c) Standard Forms
# d) Both A and B.
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)


qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\na\)"
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\na\)([\S\s]*?)\nb\)"
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nb\)([\S\s]*?)\nc\)"
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nc\)([\S\s]*?)\nd\)"
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nd\)([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\s+([a-d])'
answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value.upper() for key, value in answer}
answer_dict
# Out:
# {'1': 'D',
#  '2': 'B',
#  '3': 'A',
#  '4': 'B',
#  '5': 'D',
#  '6': 'C',
#  '7': 'D',
#  '8': 'C',
#  '9': 'A',
#  '10': 'C'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part6'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN in ['2','8']:
            break
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part6',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Which of the following is not a major process of Project Procurement Management?',
#    'choices': [{'label': 'A', 'text': 'Solicitation Planning'},
#     {'label': 'B', 'text': 'Source Selection'},
#     {'label': 'C', 'text': 'Contract Administration'},
#     {'label': 'D', 'text': 'Information Distribution'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Which of the following is not a major process of Project Procurement Management? Solicitation Planning'},
#    {'label': False,
#     'statement': 'Which of the following is not a major process of Project Procurement Management? Source Selection'},
#    {'label': False,
#     'statement': 'Which of the following is not a major process of Project Procurement Management? Contract Administration'},
#    {'label': True,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set17_statements.jsonl'

# %%
pages_to_extract = list(range(17, 23))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# Q1. On his first project assignment as the project manager, the project manager encounters
# disagreements among highly technical team members. How would the project manager BEST
# deal with the conflict?
# A) He should listen to the differences of opinions, determine what is the best choice and
# implement that choice.
# B) He should postpone further discussions, meet with each individual, and determine the best
# approach.
# C) He should listen to the differences of opinions, encourage logical discussions, and facilitate
# an agreement.
# D) He should help the team focus on agreeable aspects of their opinions and build unity by
# using relaxation techniques and common focus team building.
# Q2. Giving a team member a corner office is different than giving him health benefits because a
# corner office is a(n):
# A) Perquisite
# B) Fringe benefit
# C) use of the expectancy theory.
# D) example of formal power.
# ...

# %%
question_pattern = r"Q(\d+)\."
all_text=replaced_text = re.sub(question_pattern, lambda x: x.group(1) + ".", all_text)

print(all_text)
# Out:
# 1. On his first project assignment as the project manager, the project manager encounters
# disagreements among highly technical team members. How would the project manager BEST
# deal with the conflict?
# A) He should listen to the differences of opinions, determine what is the best choice and
# implement that choice.
# B) He should postpone further discussions, meet with each individual, and determine the best
# approach.
# C) He should listen to the differences of opinions, encourage logical discussions, and facilitate
# an agreement.
# D) He should help the team focus on agreeable aspects of their opinions and build unity by
# using relaxation techniques and common focus team building.
# 2. Giving a team member a corner office is different than giving him health benefits because a
# corner office is a(n):
# A) Perquisite
# B) Fringe benefit
# C) use of the expectancy theory.
# D) example of formal power.
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)


qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\)"
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\)([\S\s]*?)\nB\)"
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\)([\S\s]*?)\nC\)"
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\)([\S\s]*?)\nD\)"
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\)([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

# %%
answer_text="1. C\n2. A\n3. B\n4. B\n5. B\n6. A\n7. D\n8. B\n9. B\n10. A\n11. B\n12. B\n13. B\n14. B\n15. B\n16. B\n17. D\n18. D\n19. C\n20. C\n21. C\n22. A\n23. A\n24. C\n25. B\n26. C"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1. C 2. A 3. B 4. B 5. B 6. A 7. D 8. B 9. B 10. A 11. B 12. B 13. B 14. B 15. B 16. B 17. D 18. D 19. C 20. C 21. C 22. A 23. A 24. C 25. B 26. C

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom),2):
    qn=pom[i].replace('.','')
    qa=pom[i+1]
    answer_dict[qn]=qa
answer_dict
# Out:
# {'1': 'C',
#  '2': 'A',
#  '3': 'B',
#  '4': 'B',
#  '5': 'B',
#  '6': 'A',
#  '7': 'D',
#  '8': 'B',
#  '9': 'B',
#  '10': 'A',
#  '11': 'B',
#  '12': 'B',
#  '13': 'B',
#  '14': 'B',
#  '15': 'B',
#  '16': 'B',
#  '17': 'D',
#  '18': 'D',
#  '19': 'C',
#  '20': 'C',
#  '21': 'C',
#  '22': 'A',
#  '23': 'A',
#  '24': 'C',
#  '25': 'B',
#  '26': 'C'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part7'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict.get(matchQN)
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part7',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'On his first project assignment as the project manager, the project manager encounters disagreements among highly technical team members. How would the project manager BEST deal with the conflict?',
#    'choices': [{'label': 'A',
#      'text': 'He should listen to the differences of opinions, determine what is the best choice and implement that choice.'},
#     {'label': 'B',
#      'text': 'He should postpone further discussions, meet with each individual, and determine the best approach.'},
#     {'label': 'C',
#      'text': 'He should listen to the differences of opinions, encourage logical discussions, and facilitate an agreement.'},
#     {'label': 'D',
#      'text': 'He should help the team focus on agreeable aspects of their opinions and build unity by'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set18_statements.jsonl'

# %%
pages_to_extract = list(range(23, 26))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. Once Signed a contract is legally binding unless
# a) One party is unwilling to perform
# b) One party is unable to finance his part of the work
# c) It is in violation of applicable law
# d) It is declared void and null by one party
# 2. Although they may have variety of side effects, the primary objective of incentive clause in a
# contract is to
# a) Reduce costs for the buyer
# b) Help the contractor control costs
# c) Help bring the contractor’s objective in line with that of the buyer
# d) Reduce risk for the contractor by shifting risk to the buyer
# 3. With a clear Scope of Work, a contractor completes work as specified, but the buyer is not
# pleased with the results. The contract is considered to be:
# a) Incomplete because the buyer is not pleased
# b) Incomplete because the specs were incorrect
# c) Complete because the contractor is satisfied
# d) Complete because the contractor met the terms and conditions of the contract.
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\na\)."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\na\).([\S\s]*?)\nb\)."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nb\).([\S\s]*?)\nc\)."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nc\).([\S\s]*?)\nd\)."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nd\).([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\s+([a-d])'
answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value.upper() for key, value in answer}
del answer_dict["1000"]
del answer_dict["000"]
for s in sections:
    print(s.group(0))
# Out:
# 1. Once Signed a contract is legally binding unless
# a) One party is unwilling to perform
# b) One party is unable to finance his part of the work
# c) It is in violation of applicable law
# d) It is declared void and null by one party
#
# 2. Although they may have variety of side effects, the primary objective of incentive clause in a
# contract is to
# a) Reduce costs for the buyer
# b) Help the contractor control costs
# c) Help bring the contractor’s objective in line with that of the buyer
# d) Reduce risk for the contractor by shifting risk to the buyer
#
# 3. With a clear Scope of Work, a contractor completes work as specified, but the buyer is not
# pleased with the results. The contract is considered to be:
# a) Incomplete because the buyer is not pleased
# b) Incomplete because the specs were incorrect
# c) Complete because the contractor is satisfied
# d) Complete because the contractor met the terms and conditions of the contract.
#
# ...

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 1 Part6'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN=='2' or matchQN=='10' or matchQN=='11':
            break
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 1 Part6',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Once Signed a contract is legally binding unless',
#    'choices': [{'label': 'A', 'text': 'One party is unwilling to perform'},
#     {'label': 'B',
#      'text': 'One party is unable to finance his part of the work'},
#     {'label': 'C', 'text': 'It is in violation of applicable law'},
#     {'label': 'D', 'text': 'It is declared void and null by one party'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Once Signed a contract is legally binding unless One party is unwilling to perform'},
#    {'label': False,
#     'statement': 'Once Signed a contract is legally binding unless One party is unable to finance his part of the work'},
#    {'label': False,
#     'statement': 'Once Signed a contract is legally binding unless It is in violation of applicable law'},
#    {'label': True,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set2_statements.jsonl'

# %%
pages_to_extract = list(range(27, 59))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. During communication the use of __________ is a means of giving feedback to the
# speaker by rephrasing the speaker’s word to ensure that there is a good understanding of
# the message being sent.
# A. active listening.
# B. filtering .
# C. graphics.
# D. visual ,audio ,and tactile.
# 2. In communication , the receiver filter messages based on all but which of the following?
# A. Culture.
# B. Semantics.
# C. Language.
# D. Distance.
# 3. According to the PMP code of professional conduct , which of the following is a
# responsibility to the profession?
# A. Adhere to the candidate /certificate professional practice.
# B. Conflict of interest situations and other prohibited professional conduct.
# C. Quallifications, experience performance of professional services.
# D. Refrain from accepting inappropriate gifts ,payment or other compensation for personal gain.
# 4. When analyzing risks using the certainty vs uncertainty spectrum,the term “unknown-
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

# %%
all_text
# Out:
# '\n1. During communication the use of __________ is a means of giving feedback to the\nspeaker by rephrasing the speaker’s word to ensure that there is a good understanding of\nthe message being sent.\nA. active listening.\nB. filtering .\nC. graphics.\nD. visual ,audio ,and tactile.\n2. In communication , the receiver filter messages based on all but which of the following?\nA. Culture.\nB. Semantics.\nC. Language.\nD. Distance.\n3. According to the PMP code of professional conduct , which of the following is a\nresponsibility to the profession?\nA. Adhere to the candidate /certificate professional practice.\nB. Conflict of interest situations and other prohibited professional conduct.\nC. Quallifications, experience performance of professional services.\nD. Refrain from accepting inappropriate gifts ,payment or other compensation for personal gain.\n4. When analyzing risks using the certainty vs uncertainty spectrum,the term “unknown-\nunknown is best described as ___________ .\nA.
# ...

# %%
answer_text="1. A 26. C 51. A 76. A 101. A 126. C 151. C 176. B\n2. D 27. D 52. A 77. D 102. B 127. B 152. C 177. C\n3. A 28. A 53. C 78. A 103. A 128. A 153. B 178. A\n4. B 29. D 54. B 79. B 104. B 129. C 154. D 179. C\n5. B 30. A 55. D 80. A 105. C 130. C 155. D 180. D\n6. C 31. A 56. A 81. D 106. C 131. A 156. B 181. D\n7. D 32. D 57. D 82. D 107. D 132. D 157. B 182. B\n8. A 33. A 58. D 83. A 108. B 133. A 158. B 183. D\n9. B 34. D 59. C 84. C 109. D 134. D 159. C 184. A\n10. C 35. D 60. D 85. B 110. D 135. B 160. A 185. C\n11. B 36. B 61. D 86. B 111. B 136. A 161. C 186. C\n12 B 37. A 62. A 87. C 112. C 137. B 162. D 187. C\n13. B 38. B 63. C 88. A 113. C 138. C 163. D 188. A\n14. B 39. D 64. D 89. B 114. B 139. C 164. B 189. D\n15. B 40. A 65. D 90. D 115. A 140. D 165. D 190. D\n16. A 41. C 66. B 91. A 116. D 141. A 166. C 191. B\n17. D 42. C 67. C 92. C 117. D 142. D 167. B 192. B\n18. C 43. D 68. C 93. C 118. A 143. C 168. A 193. D\n19. B 44. B 69. C 94. C 119. C 144. A 169. A 194. B\n20. C 45. A 70. D 95. D 120. D 145. A 170. D 195. C\n21. A 46. C 71. B 96. D 121. B 146. C 171. B 196. D\n22. D 47. A 72. B 97. A 122. D 147. D 172. A 197. A\n23. D 48. D 73. B 98. B 123. D 148. B 173. D 198. D\n24. D 49. A 74. C 99. B 124. D 149. D 174. C 199. A\n25. B 50. D 75. A 100. D 125. D 150. C 175. A 200. C"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1. A 26. C 51. A 76. A 101. A 126. C 151. C 176. B 2. D 27. D 52. A 77. D 102. B 127. B 152. C 177. C 3. A 28. A 53. C 78. A 103. A 128. A 153. B 178. A 4. B 29. D 54. B 79. B 104. B 129. C 154. D 179. C 5. B 30. A 55. D 80. A 105. C 130. C 155. D 180. D 6. C 31. A 56. A 81. D 106. C 131. A 156. B 181. D 7. D 32. D 57. D 82. D 107. D 132. D 157. B 182. B 8. A 33. A 58. D 83. A 108. B 133. A 158. B 183. D 9. B 34. D 59. C 84. C 109. D 134. D 159. C 184. A 10. C 35. D 60. D 85. B 110. D 135. B 160. A 185. C 11. B 36. B 61. D 86. B 111. B 136. A 161. C 186. C 12 B 37. A 62. A 87. C 112. C 137. B 162. D 187. C 13. B 38. B 63. C 88. A 113. C 138. C 163. D 188. A 14. B 39. D 64. D 89. B 114. B 139. C 164. B 189. D 15. B 40. A 65. D 90. D 115. A 140. D 165. D 190. D 16. A 41. C 66. B 91. A 116. D 141. A 166. C 191. B 17. D 42. C 67. C 92. C 117. D 142. D 167. B 192. B 18. C 43. D 68. C 93. C 118. A 143. C 168. A 193. D 19. B 44. B 69. C 94. C 119. C 144. A 169. A 194. B 20. C 45. A 70. D 95
# ...

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom),2):
    qn=pom[i].replace('.','')
    qa=pom[i+1]
    answer_dict[qn]=qa
answer_dict
# Out:
# {'1': 'A',
#  '26': 'C',
#  '51': 'A',
#  '76': 'A',
#  '101': 'A',
#  '126': 'C',
#  '151': 'C',
#  '176': 'B',
#  '2': 'D',
#  '27': 'D',
#  '52': 'A',
#  '77': 'D',
#  '102': 'B',
#  '127': 'B',
#  '152': 'C',
#  '177': 'C',
#  '3': 'A',
#  '28': 'A',
#  '53': 'C',
#  '78': 'A',
#  '103': 'A',
#  '128': 'A',
#  '153': 'B',
#  '178': 'A',
#  '4': 'B',
#  '29': 'D',
#  '54': 'B',
#  '79': 'B',
#  '104': 'B',
#  '129': 'C',
#  '154': 'D',
#  '179': 'C',
#  '5': 'B',
#  '30': 'A',
#  '55': 'D',
#  '80': 'A',
#  '105': 'C',
#  '130': 'C',
#  '155': 'D',
#  '180': 'D',
#  '6': 'C',
#  '31': 'A',
#  '56': 'A',
#  '81': 'D',
#  '106': 'C',
#  '131': 'A',
#  '156': 'B',
#  '181': 'D',
#  '7': 'D',
#  '32': 'D',
#  '57': 'D',
#  '82': 'D',
#  '107': 'D',
#  '132': 'D',
#  '157': 'B',
#  '182': 'B',
#  '8': 'A',
#  '33': 'A',
#  '58': 'D',
#  '83': 'A',
#  '108': 'B',
#  '133': 'A',
#  '158': 'B',
#  '183': 'D',
#  '9': 'B',
#  '34': 'D',
#  '59': 'C',
#  '84': 'C',
#  '109': 'D',
# ...

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 2'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN in ['1','4','17','18','19','39','41','42','43','52','59','80','149','166','167','179','182','188']:
            break
        
        qadata['answerKey'] = answer_dict.get(matchQN)
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 2',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '2',
#   'question': {'stem': 'In communication , the receiver filter messages based on all but which of the following?',
#    'choices': [{'label': 'A', 'text': 'Culture.'},
#     {'label': 'B', 'text': 'Semantics.'},
#     {'label': 'C', 'text': 'Language.'},
#     {'label': 'D', 'text': 'Distance.'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'In communication , the receiver filter messages based on all but which of the following? Culture.'},
#    {'label': False,
#     'statement': 'In communication , the receiver filter messages based on all but which of the following? Semantics.'},
#    {'label': False,
#     'statement': 'In communication , the receiver filter messages based on all but which of the following? Language.'},
#    {'label': True,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set3_statements.jsonl'

# %%
pages_to_extract = list(range(60, 74))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. Regarding management and leadership all of the following are true except
# A. On a project, particularly a larger project, the project manager is generally expected to be the
# project's leader as well.
# B. Technical leadership is of primary importance in project management.
# C. Managing is primarily concerned with consistently producing key results expected by
# stakeholders.
# D. Leading involves establishing direction, aligning people, motivating and inspiring.
# 2. A company has to make a choice between two projects, because the available
# resources in money and kind are not sufficient to run both at the same time. Each project
# would take 9 months and would cost $250,000.
# 1. The first project is a process optimization which would result in a cost reduction of
# $120,000 per year. This benefit would be achieved immediately after the end of the project.
# 2. The second project would be the development of a new product which could
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

for s in sections:
    print(s.group(0))
# Out:
# 1. Regarding management and leadership all of the following are true except
# A. On a project, particularly a larger project, the project manager is generally expected to be the
# project's leader as well.
# B. Technical leadership is of primary importance in project management.
# C. Managing is primarily concerned with consistently producing key results expected by
# stakeholders.
# D. Leading involves establishing direction, aligning people, motivating and inspiring.
#
# 2. A company has to make a choice between two projects, because the available
# resources in money and kind are not sufficient to run both at the same time. Each project
# would take 9 months and would cost $250,000.
#
# 1. The first project is a process optimization which would result in a cost reduction of
# $120,000 per year. This benefit would be achieved immediately after the end of the project.
#
# 2. The second project would be the development of a new product which could
# ...

# %%
all_text
# Out:
# '\n1. Regarding management and leadership all of the following are true except\nA. On a project, particularly a larger project, the project manager is generally expected to be the\nproject\'s leader as well.\nB. Technical leadership is of primary importance in project management.\nC. Managing is primarily concerned with consistently producing key results expected by\nstakeholders.\nD. Leading involves establishing direction, aligning people, motivating and inspiring.\n2. A company has to make a choice between two projects, because the available\nresources in money and kind are not sufficient to run both at the same time. Each project\nwould take 9 months and would cost $250,000.\n1. The first project is a process optimization which would result in a cost reduction of\n$120,000 per year. This benefit would be achieved immediately after the end of the project.\n2. The second project would be the development of a new product which could\nproduce the following net profits after the end o
# ...

# %%
answer_text="1. B 26. A 51. B\n2. D 27. B 52. B\n3. B 28. C 53. A\n4. A 29. C 54. C\n5. D 30. A 55. D\n6. B 31. B 56. A\n7. C 32. D 57. C\n8. A 33. B 58. A\n9. D 34. C 59. D\n10. D 35. B 60. D\n11. A 36. A 61. A\n12. B 37. C 62. A\n13. C 38. A 63. C\n14. A 39. A 64. B\n15. C 40. B 65. A\n16. D 41. C 66. D\n17. D 42. B 67. B\n18. B 43. C 68. A\n19. D 44. C 69. B\n20. B 45. A 70. D\n21. B 46. C 71. C\n22. C 47. C 72. D\n23. D 48. D 73. A\n24. B 49. B 74. B\n25. B 50. D 75. A"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1. B 26. A 51. B 2. D 27. B 52. B 3. B 28. C 53. A 4. A 29. C 54. C 5. D 30. A 55. D 6. B 31. B 56. A 7. C 32. D 57. C 8. A 33. B 58. A 9. D 34. C 59. D 10. D 35. B 60. D 11. A 36. A 61. A 12. B 37. C 62. A 13. C 38. A 63. C 14. A 39. A 64. B 15. C 40. B 65. A 16. D 41. C 66. D 17. D 42. B 67. B 18. B 43. C 68. A 19. D 44. C 69. B 20. B 45. A 70. D 21. B 46. C 71. C 22. C 47. C 72. D 23. D 48. D 73. A 24. B 49. B 74. B 25. B 50. D 75. A

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom),2):
    qn=pom[i].replace('.','')
    qa=pom[i+1]
    answer_dict[qn]=qa
answer_dict_new={}
for i in range(1,76):
    answer_dict_new[str(i)]=answer_dict[str(i)]
answer_dict_new
# Out:
# {'1': 'B',
#  '2': 'D',
#  '3': 'B',
#  '4': 'A',
#  '5': 'D',
#  '6': 'B',
#  '7': 'C',
#  '8': 'A',
#  '9': 'D',
#  '10': 'D',
#  '11': 'A',
#  '12': 'B',
#  '13': 'C',
#  '14': 'A',
#  '15': 'C',
#  '16': 'D',
#  '17': 'D',
#  '18': 'B',
#  '19': 'D',
#  '20': 'B',
#  '21': 'B',
#  '22': 'C',
#  '23': 'D',
#  '24': 'B',
#  '25': 'B',
#  '26': 'A',
#  '27': 'B',
#  '28': 'C',
#  '29': 'C',
#  '30': 'A',
#  '31': 'B',
#  '32': 'D',
#  '33': 'B',
#  '34': 'C',
#  '35': 'B',
#  '36': 'A',
#  '37': 'C',
#  '38': 'A',
#  '39': 'A',
#  '40': 'B',
#  '41': 'C',
#  '42': 'B',
#  '43': 'C',
#  '44': 'C',
#  '45': 'A',
#  '46': 'C',
#  '47': 'C',
#  '48': 'D',
#  '49': 'B',
#  '50': 'D',
#  '51': 'B',
#  '52': 'B',
#  '53': 'A',
#  '54': 'C',
#  '55': 'D',
#  '56': 'A',
#  '57': 'C',
#  '58': 'A',
#  '59': 'D',
#  '60': 'D',
#  '61': 'A',
#  '62': 'A',
#  '63': 'C',
#  '64': 'B',
#  '65': 'A',
#  '66': 'D',
#  '67': 'B',
#  '68': 'A',
#  '69': 'B',
#  '70': 'D',
#  '71': 'C',
#  '72': 'D',
# ...

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 3'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN not in answer_dict_new.keys():
            break
        qadata['answerKey'] = answer_dict_new.get(matchQN)
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 3',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Regarding management and leadership all of the following are true except',
#    'choices': [{'label': 'A',
#      'text': "On a project, particularly a larger project, the project manager is generally expected to be the project's leader as well."},
#     {'label': 'B',
#      'text': 'Technical leadership is of primary importance in project management.'},
#     {'label': 'C',
#      'text': 'Managing is primarily concerned with consistently producing key results expected by stakeholders.'},
#     {'label': 'D',
#      'text': 'Leading involves establishing direction, aligning people, motivating and inspiring.'}]},
#   'answerKey': 'B',
#   'statements': [{'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set4_statements.jsonl'

# %%
pages_to_extract = list(range(75, 82))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1 Project communication management includes the process required to ensure
# A timely and appropriate generation collection and dissemination of project information
# B storage and ultimate disposition of project information
# C critical links among people, ideas and information
# D all the above
# 2 Communication planning in a project determines
# A who needs what information
# B when will they need it and how will it be given
# C key performance reports to be circulated among stake holders
# D a and b
# 3 Following are some of the tools and techniques in project communication management
# except
# A stakeholder analysis [1]
# B earned value analysis [2]
# C presentation techniques
# D performance reviews [3]
# 4 On most of the projects the majority of communication planning is done as part of
# A project initiation
# B project planning
# C project execution
# D a and b
# 5 The results of communication planning will be reviewed and revised as needed
# A project execution phase
# ...

# %%
section = r"^\d+\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\s+([\S\s]*?)\nA"
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA([\S\s]*?)\nB"
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB([\S\s]*?)\nC"
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC([\S\s]*?)\nD"
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

# %%
all_text
# Out:
# '\n1 Project communication management includes the process required to ensure\nA timely and appropriate generation collection and dissemination of project information\nB storage and ultimate disposition of project information\nC critical links among people, ideas and information\nD all the above\n2 Communication planning in a project determines\nA who needs what information\nB when will they need it and how will it be given\nC key performance reports to be circulated among stake holders\nD a and b\n3 Following are some of the tools and techniques in project communication management\nexcept\nA stakeholder analysis [1]\nB earned value analysis [2]\nC presentation techniques\nD performance reviews [3]\n4 On most of the projects the majority of communication planning is done as part of\nA project initiation\nB project planning\nC project execution\nD a and b\n5 The results of communication planning will be reviewed and revised as needed\nA project execution phase\nB project controlling p
# ...

# %%
answer_text="1. D 11. B 21. C 31. D 2. D 12. D 22. D 32 B 3. C 13. D 23. D 33. C 43. D\n4. B 14. D 24. D 34. C 44. D\n5. C 15. C 25. C 35. D 45. D\n6. D 16. D 26. D 36. A 46. D\n7. D 17. D 27. D 37. D 47. D\n8. A 18. C 28. D 48. A\n9. A 19. C 29. D 49. D\n10. D 20. B 30. D 50. D"

# %%
answer_text = answer_text.replace("\n", " ")

print(answer_text)
# Out:
# 1. D 11. B 21. C 31. D 2. D 12. D 22. D 32 B 3. C 13. D 23. D 33. C 43. D 4. B 14. D 24. D 34. C 44. D 5. C 15. C 25. C 35. D 45. D 6. D 16. D 26. D 36. A 46. D 7. D 17. D 27. D 37. D 47. D 8. A 18. C 28. D 48. A 9. A 19. C 29. D 49. D 10. D 20. B 30. D 50. D

# %%
pom=answer_text.split(" ")
answer_dict={}
for i in range(0,len(pom),2):
    qn=pom[i].replace('.','')
    qa=pom[i+1]
    answer_dict[qn]=qa
answer_dict
# Out:
# {'1': 'D',
#  '11': 'B',
#  '21': 'C',
#  '31': 'D',
#  '2': 'D',
#  '12': 'D',
#  '22': 'D',
#  '32': 'B',
#  '3': 'C',
#  '13': 'D',
#  '23': 'D',
#  '33': 'C',
#  '43': 'D',
#  '4': 'B',
#  '14': 'D',
#  '24': 'D',
#  '34': 'C',
#  '44': 'D',
#  '5': 'C',
#  '15': 'C',
#  '25': 'C',
#  '35': 'D',
#  '45': 'D',
#  '6': 'D',
#  '16': 'D',
#  '26': 'D',
#  '36': 'A',
#  '46': 'D',
#  '7': 'D',
#  '17': 'D',
#  '27': 'D',
#  '37': 'D',
#  '47': 'D',
#  '8': 'A',
#  '18': 'C',
#  '28': 'D',
#  '48': 'A',
#  '9': 'A',
#  '19': 'C',
#  '29': 'D',
#  '49': 'D',
#  '10': 'D',
#  '20': 'B',
#  '30': 'D',
#  '50': 'D'}

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 4'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        if matchQN =='24' or matchQN=='27' or matchQN=='31' or matchQN=='36':
            break
        qadata['answerKey'] = answer_dict.get(matchQN)
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        if qadata['answerKey']!=None:
            pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 4',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'Project communication management includes the process required to ensure',
#    'choices': [{'label': 'A',
#      'text': 'timely and appropriate generation collection and dissemination of project information'},
#     {'label': 'B',
#      'text': 'storage and ultimate disposition of project information'},
#     {'label': 'C',
#      'text': 'critical links among people, ideas and information'},
#     {'label': 'D', 'text': 'all the above'}]},
#   'answerKey': 'D',
#   'statements': [{'label': False,
#     'statement': 'Project communication management includes the process required to ensure timely and appropriate generation collection and dissemination of project information'},
#    {'label': False,
#     'statement': 'Project communication management includes the process required to ensure storage and ultimate disposition of project information'},
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set5_statements.jsonl'

# %%
pages_to_extract = list(range(83, 120))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. A Project Manager is most likely to have the strongest influence in an organization that
# is:
# A. Balanced Matrix
# B. Functional
# C. Projectized
# D. Strong Matrix
# 2. Project Management processes are:
# A. A series of actions bringing about a result
# B. Concerned with describing and organizing the work of the project
# C. Concerned with specifying and creating the product
# D. Broken into core and non-core processes
# 3. Executing processes are concerned with:
# A. Recognizing that a project or phase should begin
# B. Coordinating people and other resources to carry out the plan
# C. Devising and maintaining a workable method to accomplish the business need that the project
# was undertaken to address
# D. Ensuring that the project objectives are met by monitoring and measuring progress
# and taking corrective action when necessary
# 4. Controlling processes are concerned with:
# A. Coordinating people and other resources to carry out the plan
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\.([A-D])'
answers = re.findall(answer_pattern, all_text)

answer_dict = {key: value for key, value in answers}

print(answer_dict)
# Out:
# {'58': 'A', '89': 'D', '1': 'C', '2': 'B', '3': 'B', '4': 'C', '5': 'C', '6': 'D', '7': 'A', '8': 'B', '9': 'D', '10': 'A', '11': 'B', '12': 'C', '13': 'D', '14': 'A', '15': 'B', '16': 'C', '17': 'D', '18': 'A', '19': 'C', '20': 'B', '21': 'D', '22': 'D', '23': 'D', '24': 'B', '25': 'D', '26': 'A', '27': 'B', '28': 'B', '29': 'A', '30': 'C', '31': 'C', '32': 'B', '33': 'B', '34': 'A', '35': 'D', '36': 'C', '37': 'B', '38': 'B', '39': 'A', '40': 'D', '41': 'C', '42': 'A', '43': 'B', '44': 'D', '45': 'D', '46': 'C', '47': 'B', '48': 'A', '49': 'B', '50': 'C', '51': 'C', '52': 'D', '53': 'A', '54': 'B', '55': 'C', '56': 'D', '57': 'C', '59': 'A', '60': 'C', '61': 'D', '62': 'C', '63': 'C', '64': 'D', '65': 'C', '66': 'A', '67': 'C', '68': 'B', '69': 'D', '70': 'B', '71': 'C', '72': 'C', '73': 'B', '74': 'A', '75': 'A', '76': 'B', '77': 'C', '78': 'C', '79': 'C', '80': 'D', '81': 'D', '82': 'C', '83': 'A', '84': 'B', '85': 'D', '86': 'C', '87': 'B', '88': 'B', '90': 'A', '91': 'A', '92':
# ...

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 5'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
    
        
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 5',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '1',
#   'question': {'stem': 'A Project Manager is most likely to have the strongest influence in an organization that is:',
#    'choices': [{'label': 'A', 'text': 'Balanced Matrix'},
#     {'label': 'B', 'text': 'Functional'},
#     {'label': 'C', 'text': 'Projectized'},
#     {'label': 'D', 'text': 'Strong Matrix'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'A Project Manager is most likely to have the strongest influence in an organization that is: Balanced Matrix'},
#    {'label': False,
#     'statement': 'A Project Manager is most likely to have the strongest influence in an organization that is: Functional'},
#    {'label': True,
#     'statement': 'A Project Manager is most likely to have the strongest influence in an organization that is: Projectized'},
#    {'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')

# %%
# import libraries
import re
import pdfplumber
import json

# %%
# define PDF file path
file_name = 'PMP-Exam-Question-Bank 1440'
input_file = file_name + '.pdf'
output_file = file_name + '_set6_statements.jsonl'

# %%
pages_to_extract = list(range(121, 164))

    
all_text = ""

with pdfplumber.open(input_file) as pdf:
    for page_num, page in enumerate(pdf.pages):
        if page_num + 1 in pages_to_extract:
            page_text = page.extract_text()
            if page_text:
                all_text += '\n' + page_text
print(all_text)
# Out:
# 1. "A Project Manager is at the project kick-off meeting. He confidently states the vision
# and mission for the project. This PM is exhibiting the following leadership style:
# A. Hierarchal
# B. Authoritarian
# C. Charismatic
# D. Associative
# 2. You are in charge of developing a new product for a bank. Your quality metrics are
# based on the 80th percentile of each of the last three products developed. This is an
# example of:
# A. Statistical sampling
# B. Metrics
# C. Benchmarking
# D. Operational definitions
# 3. The two closing procedures are called:
# A. Contract close out and scope verification
# B. Contract close out and administrative closure
# C. Project closure and product verification
# D. Project closure and lessons learned
# 4. Scoring models, comparative approaches and benefit contribution are all part of:
# A. Constrained optimization models for selecting a project
# B. Benefit measurement models for selecting a project
# C. Quality measurement techniques
# ...

# %%
section = r"^\d+\.\s+([\S\s]*?)(?=\Z|^\d+\.\s+)"
# capture sections from question to question
sections = re.finditer(section, all_text, re.MULTILINE)

qnumber = r"(^\d+)\.\s+[\S\s]"
qnumbers = re.finditer(qnumber, all_text, re.MULTILINE)

question = r"\d+\.\s+([\S\s]*?)\nA\."
questions = re.finditer(question, all_text, re.MULTILINE)

choiceA = r"\nA\.([\S\s]*?)\nB\."
choiceAs = re.finditer(choiceA, all_text, re.MULTILINE)

choiceB = r"\nB\.([\S\s]*?)\nC\."
choiceBs = re.finditer(choiceB, all_text, re.MULTILINE)

choiceC = r"\nC\.([\S\s]*?)\nD\."
choiceCs = re.finditer(choiceC, all_text, re.MULTILINE)

choiceD = r"\nD\.([\S\s]*?)\n"
choiceDs = re.finditer(choiceD, all_text, re.MULTILINE)

answer_pattern = r'(\d+)\.\s+([A-D])'
answer = re.findall(answer_pattern, all_text)
answer_dict = {key: value for key, value in answer}
answer_dict
# Out:
# {'5': 'C',
#  '8': 'C',
#  '16': 'C',
#  '21': 'A',
#  '27': 'C',
#  '29': 'B',
#  '30': 'A',
#  '37': 'C',
#  '38': 'A',
#  '39': 'B',
#  '48': 'A',
#  '49': 'D',
#  '50': 'D',
#  '51': 'A',
#  '43': 'B',
#  '120': 'C',
#  '100': 'D',
#  '47': 'D',
#  '54': 'A',
#  '57': 'A',
#  '58': 'C',
#  '66': 'A',
#  '69': 'C',
#  '76': 'C',
#  '78': 'A',
#  '81': 'B',
#  '82': 'A',
#  '86': 'C',
#  '88': 'D',
#  '89': 'C',
#  '94': 'B',
#  '102': 'A',
#  '103': 'B',
#  '112': 'A',
#  '113': 'B',
#  '114': 'A',
#  '115': 'D',
#  '116': 'B',
#  '119': 'C',
#  '121': 'D',
#  '128': 'A',
#  '130': 'C',
#  '131': 'A',
#  '134': 'B',
#  '143': 'A',
#  '144': 'C',
#  '152': 'D',
#  '156': 'A',
#  '157': 'B',
#  '158': 'A',
#  '168': 'C',
#  '172': 'A',
#  '174': 'A',
#  '175': 'B',
#  '177': 'D',
#  '180': 'A',
#  '184': 'B',
#  '186': 'D',
#  '189': 'C',
#  '190': 'B',
#  '191': 'D',
#  '203': 'C',
#  '205': 'B',
#  '213': 'B',
#  '216': 'A',
#  '217': 'D',
#  '7000': 'B',
#  '239': 'B',
# ...

# %%
import re
import unicodedata  # Module Unicode

matchesS = re.finditer(section, all_text, re.MULTILINE)
pmpqa = []

for sectionNum, sectionMatch in enumerate(matchesS):
    matchesQN = re.findall(qnumber, sectionMatch.group(0), re.MULTILINE)
    matchesQ = re.findall(question, sectionMatch.group(0), re.MULTILINE)
    matchesA = re.findall(choiceA, sectionMatch.group(0), re.MULTILINE)
    matchesB = re.findall(choiceB, sectionMatch.group(0), re.MULTILINE)
    matchesC = re.findall(choiceC, sectionMatch.group(0), re.MULTILINE)
    matchesD = re.findall(choiceD, sectionMatch.group(0), re.MULTILINE)
    
    for matchQN, matchQ, matchA, matchB, matchC, matchD in zip(matchesQN, matchesQ, matchesA, matchesB, matchesC, matchesD):
        # Normalize Unicode characters to their closest ASCII representation
        # This removes accents and converts special characters like '\u2018' and '\u2019' to standard ASCII equivalents.
        matchQ = unicodedata.normalize('NFKD', matchQ).encode('ascii', 'ignore').decode('utf-8')
        matchA = unicodedata.normalize('NFKD', matchA).encode('ascii', 'ignore').decode('utf-8')
        matchB = unicodedata.normalize('NFKD', matchB).encode('ascii', 'ignore').decode('utf-8')
        matchC = unicodedata.normalize('NFKD', matchC).encode('ascii', 'ignore').decode('utf-8')
        matchD = unicodedata.normalize('NFKD', matchD).encode('ascii', 'ignore').decode('utf-8')
        
        qadata = {}
        qadata['source'] = 'PMP Exam Question bank Set 6'
        qadata['year'] = 2020
        qadata['type'] = 'question bank'
        qadata['qid'] = matchQN
        qadata['question'] = {"stem": matchQ.replace('\n',' ').strip(),
                              "choices": [
                                  {"label": "A", "text": matchA.replace('\n',' ').strip()},
                                  {"label": "B", "text": matchB.replace('\n',' ').strip()},
                                  {"label": "C", "text": matchC.replace('\n',' ').strip()},
                                  {"label": "D", "text": matchD.replace('\n',' ').strip()}]}
        
        if matchQN not in answer_dict.keys():
            break
            
        qadata['answerKey'] = answer_dict[matchQN]
        
        statements = []
        for choice, text in zip(['A', 'B', 'C', 'D'], [matchA, matchB, matchC, matchD]):
            is_correct = (answer_dict.get(matchQN) == choice)
            statements.append({
                "label": is_correct,
                "statement": matchQ.replace('\n',' ').strip() + ' ' + text.replace('\n', ' ').strip()
            })
            
        qadata['statements'] = statements
        pmpqa.append(qadata)

pmpqa
# Out:
# [{'source': 'PMP Exam Question bank Set 6',
#   'year': 2020,
#   'type': 'question bank',
#   'qid': '2',
#   'question': {'stem': 'You are in charge of developing a new product for a bank. Your quality metrics are based on the 80th percentile of each of the last three products developed. This is an example of:',
#    'choices': [{'label': 'A', 'text': 'Statistical sampling'},
#     {'label': 'B', 'text': 'Metrics'},
#     {'label': 'C', 'text': 'Benchmarking'},
#     {'label': 'D', 'text': 'Operational definitions'}]},
#   'answerKey': 'C',
#   'statements': [{'label': False,
#     'statement': 'You are in charge of developing a new product for a bank. Your quality metrics are based on the 80th percentile of each of the last three products developed. This is an example of: Statistical sampling'},
#    {'label': False,
# ...

# %%
# save the PMP-QA dataset as jsonl
with open(output_file, 'w') as fout:
    for dic in pmpqa:
        fout.write(json.dumps(dic) + '\n')
